# %% [markdown]
# # Training and Testing Datasets
#
# > Athina Davari 8180020 \
# > Department of Management Science and Technology \
# > Athens University of Economics and Business
#
# ## Description
# Create the training and testing datasets for dissect Spotify's Valence assignment.
#
# ## Setting the Scene
# For data analysis process, its necessary to import the packages we'll need.\
# As a good practice, at the begining of the notebook we have a cell with all the imports.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotify_config import config
import pandas as pd

# %% [markdown]
# In order to run the notebook, you should have a spotify developers account, create an application and add to `spotify_config.py` file your spotify `client_id` and `client_secret`, so that your app will be able to use the Spotify API:
#
# `spotify_config.py`:
#
#  ```
#   config = {
#       'client_id' : 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX',
#       'client_secret' :'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'
#   }
#   ```

# %%
client_credentials_manager = SpotifyClientCredentials(config['client_id'],
                                                      config['client_secret'])
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ## Training Dataset
#
# In order to create the random dataset, i found first the [Music Map of all genres on spotify](
# https://everynoise.com/everynoise1d.cgi?scope=all&vector=popularity). Then i downloaded the html page, cleaned up html and saved it as `site.html`.
#
# From that page i took all the Spotify genres.

# %%
music_types = pd.read_html('site.html')[0]
music_types.drop(1, axis=1, inplace=True)
music_types
# Out:
#          0                      2
# 0        1                    pop
# 1        2              dance pop
# 2        3                    rap
# 3        4                   rock
# 4        5                  latin
# ...    ...                    ...
# 5751  5752     yunnan traditional
# 5752  5753      swazi traditional
# 5753  5754  classical string trio
# 5754  5755          himene tarava
# 5755  5756        youth orchestra
#
# [5756 rows x 2 columns]

# %% [markdown]
# I searched for 50 tracks for the 450 most popular categories.

# %%
df = pd.DataFrame(columns = ['id', 'name'])
x = range(450)
for n in x:
    genre = music_types[2].iloc[n]
    tracks1 = sp.search(q='genre:'+genre, type="track", limit=50)
    tracks1
    x = tracks1.get("tracks")
    y = x.get("items")
    for track in y:
        df = df.append({'id' : track['id'], 'name' : track['name']}, 
                         ignore_index = True)

print("Unique songs")
print(len(df["id"].unique()))
# Out:
# Unique songs
# 17608

# %%
df
# Out:
#                            id                                     name
# 0      4fouWK6XVHhzl78KzQ1UjL                                  abcdefu
# 1      3Vi5XqYrmQgOYBajMWSvCi                             Need to Know
# 2      4ZtFanR9U6ndgddUvNcjcG                                 good 4 u
# 3      6Uj1ctrBOjOas8xZXGqKk4                                    Woman
# 4      27NovPIUIRrOZoCHxABJwK        INDUSTRY BABY (feat. Jack Harlow)
# ...                       ...                                      ...
# 20546  3Evwk0LpaDBxZw5XivAnAW     Te Olvidaré (feat. Demarco Flamenco)
# 20547  6lVnWrqFYadbLQQXJ3eSbq                     Una pequeña historia
# 20548  6o70OF4tqIT43azQ8gR7Y6                                 Flamenco
# 20549  62QYD9QijBwm26Id8azkcR        New Mego's Flamenco - Boston Show
# 20550  7APrqpJyEIkUMEtKerIz88  Costa Del Sol (En Inciterende Flamenco)
#
# [20551 rows x 2 columns]

# %%
df.drop_duplicates()
# Out:
#                            id                                     name
# 0      4fouWK6XVHhzl78KzQ1UjL                                  abcdefu
# 1      3Vi5XqYrmQgOYBajMWSvCi                             Need to Know
# 2      4ZtFanR9U6ndgddUvNcjcG                                 good 4 u
# 3      6Uj1ctrBOjOas8xZXGqKk4                                    Woman
# 4      27NovPIUIRrOZoCHxABJwK        INDUSTRY BABY (feat. Jack Harlow)
# ...                       ...                                      ...
# 20546  3Evwk0LpaDBxZw5XivAnAW     Te Olvidaré (feat. Demarco Flamenco)
# 20547  6lVnWrqFYadbLQQXJ3eSbq                     Una pequeña historia
# 20548  6o70OF4tqIT43azQ8gR7Y6                                 Flamenco
# 20549  62QYD9QijBwm26Id8azkcR        New Mego's Flamenco - Boston Show
# 20550  7APrqpJyEIkUMEtKerIz88  Costa Del Sol (En Inciterende Flamenco)
#
# [17608 rows x 2 columns]

# %% [markdown]
# Then i got, for each of the tracks, its audio features.
#
# In order to do that, i created a dictionary keyed by id, with values being the audio features for the specific track.

# %%
features = {}
all_track_ids = list(df['id'].unique())
start = 0
num_tracks = 100
  
while start < len(all_track_ids):
    print(f'getting from {start} to {start+num_tracks}')
    tracks_batch = all_track_ids[start:start+num_tracks]
    features_batch = sp.audio_features(tracks_batch)
    features.update({ track_id : track_features 
                     for track_id, track_features in zip(tracks_batch, features_batch) })
    start += num_tracks
# Out:
# getting from 0 to 100
# getting from 100 to 200
# getting from 200 to 300
# getting from 300 to 400
# getting from 400 to 500
# getting from 500 to 600
# getting from 600 to 700
# getting from 700 to 800
# getting from 800 to 900
# getting from 900 to 1000
# getting from 1000 to 1100
# getting from 1100 to 1200
# getting from 1200 to 1300
# getting from 1300 to 1400
# getting from 1400 to 1500
# getting from 1500 to 1600
# getting from 1600 to 1700
# getting from 1700 to 1800
# getting from 1800 to 1900
# getting from 1900 to 2000
# getting from 2000 to 2100
# getting from 2100 to 2200
# getting from 2200 to 2300
# getting from 2300 to 2400
# getting from 2400 to 2500
# getting from 2500 to 2600
# getting from 2600 to 2700
# getting from 2700 to 2800
# getting from 2800 to 2900
# getting from 2900 to 3000
# getting from 3000 to 3100
# getting from 3100 to 3200
# getting from 3200 to 3300
# getting from 3300 to 3400
# getting from 3400 to 3500
# getting from 3500 to 3600
# getting from 3600 to 3700
# getting from 3700 to 3800
# getting from 3800 to 3900
# getting from 3900 to 4000
# getting from 4000 to 4100
# getting from 4100 to 4200
# getting from 4200 to 4300
# getting from 4300 to 4400
# getting from 4400 to 4500
# getting from 4500 to 4600
# getting from 4600 to 4700
# getting from 4700 to 4800
# getting from 4800 to 4900
# getting from 4900 to 5000
# getting from 5000 to 5100
# getting from 5100 to 5200
# getting from 5200 to 5300
# getting from 5300 to 5400
# getting from 5400 to 5500
# getting from 5500 to 5600
# getting from 5600 to 5700
# getting from 5700 to 5800
# getting from 5800 to 5900
# getting from 5900 to 6000
# getting from 6000 to 6100
# getting from 6100 to 6200
# getting from 6200 to 6300
# getting from 6300 to 6400
# getting from 6400 to 6500
# getting from 6500 to 6600
# getting from 6600 to 6700
# getting from 6700 to 6800
# getting from 6800 to 6900
# getting from 6900 to 7000
# getting from 7000 to 7100
# getting from 7100 to 7200
# getting from 7200 to 7300
# getting from 7300 to 7400
# getting from 7400 to 7500
# getting from 7500 to 7600
# getting from 7600 to 7700
# getting from 7700 to 7800
# getting from 7800 to 7900
# getting from 7900 to 8000
# getting from 8000 to 8100
# getting from 8100 to 8200
# getting from 8200 to 8300
# getting from 8300 to 8400
# getting from 8400 to 8500
# getting from 8500 to 8600
# getting from 8600 to 8700
# getting from 8700 to 8800
# getting from 8800 to 8900
# getting from 8900 to 9000
# getting from 9000 to 9100
# getting from 9100 to 9200
# getting from 9200 to 9300
# getting from 9300 to 9400
# getting from 9400 to 9500
# getting from 9500 to 9600
# getting from 9600 to 9700
# getting from 9700 to 9800
# getting from 9800 to 9900
# getting from 9900 to 10000
# getting from 10000 to 10100
# getting from 10100 to 10200
# getting from 10200 to 10300
# getting from 10300 to 10400
# getting from 10400 to 10500
# getting from 10500 to 10600
# getting from 10600 to 10700
# getting from 10700 to 10800
# getting from 10800 to 10900
# getting from 10900 to 11000
# getting from 11000 to 11100
# getting from 11100 to 11200
# getting from 11200 to 11300
# getting from 11300 to 11400
# getting from 11400 to 11500
# getting from 11500 to 11600
# getting from 11600 to 11700
# getting from 11700 to 11800
# getting from 11800 to 11900
# getting from 11900 to 12000
# getting from 12000 to 12100
# getting from 12100 to 12200
# getting from 12200 to 12300
# getting from 12300 to 12400
# getting from 12400 to 12500
# getting from 12500 to 12600
# getting from 12600 to 12700
# getting from 12700 to 12800
# getting from 12800 to 12900
# getting from 12900 to 13000
# getting from 13000 to 13100
# getting from 13100 to 13200
# getting from 13200 to 13300
# getting from 13300 to 13400
# getting from 13400 to 13500
# getting from 13500 to 13600
# getting from 13600 to 13700
# getting from 13700 to 13800
# getting from 13800 to 13900
# getting from 13900 to 14000
# getting from 14000 to 14100
# getting from 14100 to 14200
# getting from 14200 to 14300
# getting from 14300 to 14400
# getting from 14400 to 14500
# getting from 14500 to 14600
# getting from 14600 to 14700
# getting from 14700 to 14800
# getting from 14800 to 14900
# getting from 14900 to 15000
# getting from 15000 to 15100
# getting from 15100 to 15200
# getting from 15200 to 15300
# getting from 15300 to 15400
# getting from 15400 to 15500
# getting from 15500 to 15600
# getting from 15600 to 15700
# getting from 15700 to 15800
# getting from 15800 to 15900
# getting from 15900 to 16000
# getting from 16000 to 16100
# getting from 16100 to 16200
# getting from 16200 to 16300
# getting from 16300 to 16400
# getting from 16400 to 16500
# getting from 16500 to 16600
# getting from 16600 to 16700
# getting from 16700 to 16800
# getting from 16800 to 16900
# getting from 16900 to 17000
# getting from 17000 to 17100
# getting from 17100 to 17200
# getting from 17200 to 17300
# getting from 17300 to 17400
# getting from 17400 to 17500
# getting from 17500 to 17600
# getting from 17600 to 17700

# %% [markdown]
# And this is how the features look like:

# %%
features
# Out:
# {'4fouWK6XVHhzl78KzQ1UjL': {'danceability': 0.695,
#   'energy': 0.54,
#   'key': 4,
#   'loudness': -5.692,
#   'mode': 1,
#   'speechiness': 0.0493,
#   'acousticness': 0.299,
#   'instrumentalness': 0,
#   'liveness': 0.367,
#   'valence': 0.415,
#   'tempo': 121.932,
#   'type': 'audio_features',
#   'id': '4fouWK6XVHhzl78KzQ1UjL',
#   'uri': 'spotify:track:4fouWK6XVHhzl78KzQ1UjL',
#   'track_href': 'https://api.spotify.com/v1/tracks/4fouWK6XVHhzl78KzQ1UjL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4fouWK6XVHhzl78KzQ1UjL',
#   'duration_ms': 168602,
#   'time_signature': 4},
#  '3Vi5XqYrmQgOYBajMWSvCi': {'danceability': 0.664,
#   'energy': 0.609,
#   'key': 1,
#   'loudness': -6.509,
#   'mode': 1,
#   'speechiness': 0.0707,
#   'acousticness': 0.304,
#   'instrumentalness': 0,
#   'liveness': 0.0926,
#   'valence': 0.194,
#   'tempo': 130.041,
#   'type': 'audio_features',
#   'id': '3Vi5XqYrmQgOYBajMWSvCi',
#   'uri': 'spotify:track:3Vi5XqYrmQgOYBajMWSvCi',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Vi5XqYrmQgOYBajMWSvCi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Vi5XqYrmQgOYBajMWSvCi',
#   'duration_ms': 210560,
#   'time_signature': 4},
#  '4ZtFanR9U6ndgddUvNcjcG': {'danceability': 0.563,
#   'energy': 0.664,
#   'key': 9,
#   'loudness': -5.044,
#   'mode': 1,
#   'speechiness': 0.154,
#   'acousticness': 0.335,
#   'instrumentalness': 0,
#   'liveness': 0.0849,
#   'valence': 0.688,
#   'tempo': 166.928,
#   'type': 'audio_features',
#   'id': '4ZtFanR9U6ndgddUvNcjcG',
#   'uri': 'spotify:track:4ZtFanR9U6ndgddUvNcjcG',
#   'track_href': 'https://api.spotify.com/v1/tracks/4ZtFanR9U6ndgddUvNcjcG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ZtFanR9U6ndgddUvNcjcG',
#   'duration_ms': 178147,
#   'time_signature': 4},
#  '6Uj1ctrBOjOas8xZXGqKk4': {'danceability': 0.824,
#   'energy': 0.764,
#   'key': 5,
#   'loudness': -4.175,
#   'mode': 0,
#   'speechiness': 0.0854,
#   'acousticness': 0.0888,
#   'instrumentalness': 0.00294,
#   'liveness': 0.117,
#   'valence': 0.881,
#   'tempo': 107.998,
#   'type': 'audio_features',
#   'id': '6Uj1ctrBOjOas8xZXGqKk4',
#   'uri': 'spotify:track:6Uj1ctrBOjOas8xZXGqKk4',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Uj1ctrBOjOas8xZXGqKk4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Uj1ctrBOjOas8xZXGqKk4',
#   'duration_ms': 172627,
#   'time_signature': 4},
#  '27NovPIUIRrOZoCHxABJwK': {'danceability': 0.736,
#   'energy': 0.704,
#   'key': 3,
#   'loudness': -7.409,
#   'mode': 0,
#   'speechiness': 0.0615,
#   'acousticness': 0.0203,
#   'instrumentalness': 0,
#   'liveness': 0.0501,
#   'valence': 0.894,
#   'tempo': 149.995,
#   'type': 'audio_features',
#   'id': '27NovPIUIRrOZoCHxABJwK',
#   'uri': 'spotify:track:27NovPIUIRrOZoCHxABJwK',
#   'track_href': 'https://api.spotify.com/v1/tracks/27NovPIUIRrOZoCHxABJwK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/27NovPIUIRrOZoCHxABJwK',
#   'duration_ms': 212000,
#   'time_signature': 4},
#  '0gplL1WMoJ6iYaPgMCL0gX': {'danceability': 0.604,
#   'energy': 0.366,
#   'key': 5,
#   'loudness': -7.519,
#   'mode': 1,
#   'speechiness': 0.0282,
#   'acousticness': 0.578,
#   'instrumentalness': 0,
#   'liveness': 0.133,
#   'valence': 0.13,
#   'tempo': 141.981,
#   'type': 'audio_features',
#   'id': '0gplL1WMoJ6iYaPgMCL0gX',
#   'uri': 'spotify:track:0gplL1WMoJ6iYaPgMCL0gX',
#   'track_href': 'https://api.spotify.com/v1/tracks/0gplL1WMoJ6iYaPgMCL0gX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0gplL1WMoJ6iYaPgMCL0gX',
#   'duration_ms': 224695,
#   'time_signature': 4},
#  '5dXWFMwD7I7zXsInONVl0H': {'danceability': 0.535,
#   'energy': 0.388,
#   'key': 7,
#   'loudness': -9.805,
#   'mode': 0,
#   'speechiness': 0.155,
#   'acousticness': 0.507,
#   'instrumentalness': 0,
#   'liveness': 0.11,
#   'valence': 0.412,
#   'tempo': 106.703,
#   'type': 'audio_features',
#   'id': '5dXWFMwD7I7zXsInONVl0H',
#   'uri': 'spotify:track:5dXWFMwD7I7zXsInONVl0H',
#   'track_href': 'https://api.spotify.com/v1/tracks/5dXWFMwD7I7zXsInONVl0H',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5dXWFMwD7I7zXsInONVl0H',
#   'duration_ms': 174000,
#   'time_signature': 5},
#  '3USxtqRwSYz57Ewm6wWRMp': {'danceability': 0.761,
#   'energy': 0.525,
#   'key': 11,
#   'loudness': -6.9,
#   'mode': 1,
#   'speechiness': 0.0944,
#   'acousticness': 0.44,
#   'instrumentalness': 6.7e-06,
#   'liveness': 0.0921,
#   'valence': 0.531,
#   'tempo': 80.87,
#   'type': 'audio_features',
#   'id': '3USxtqRwSYz57Ewm6wWRMp',
#   'uri': 'spotify:track:3USxtqRwSYz57Ewm6wWRMp',
#   'track_href': 'https://api.spotify.com/v1/tracks/3USxtqRwSYz57Ewm6wWRMp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3USxtqRwSYz57Ewm6wWRMp',
#   'duration_ms': 238805,
#   'time_signature': 4},
#  '0e8nrvls4Qqv5Rfa2UhqmO': {'danceability': 0.737,
#   'energy': 0.846,
#   'key': 1,
#   'loudness': -4.51,
#   'mode': 0,
#   'speechiness': 0.22,
#   'acousticness': 0.00614,
#   'instrumentalness': 0,
#   'liveness': 0.0486,
#   'valence': 0.546,
#   'tempo': 87.981,
#   'type': 'audio_features',
#   'id': '0e8nrvls4Qqv5Rfa2UhqmO',
#   'uri': 'spotify:track:0e8nrvls4Qqv5Rfa2UhqmO',
#   'track_href': 'https://api.spotify.com/v1/tracks/0e8nrvls4Qqv5Rfa2UhqmO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0e8nrvls4Qqv5Rfa2UhqmO',
#   'duration_ms': 143901,
#   'time_signature': 4},
#  '50nfwKoDiSYg8zOCREWAm5': {'danceability': 0.788,
#   'energy': 0.859,
#   'key': 2,
#   'loudness': -2.724,
#   'mode': 1,
#   'speechiness': 0.0856,
#   'acousticness': 0.281,
#   'instrumentalness': 0,
#   'liveness': 0.0424,
#   'valence': 0.822,
#   'tempo': 141.02,
#   'type': 'audio_features',
#   'id': '50nfwKoDiSYg8zOCREWAm5',
#   'uri': 'spotify:track:50nfwKoDiSYg8zOCREWAm5',
#   'track_href': 'https://api.spotify.com/v1/tracks/50nfwKoDiSYg8zOCREWAm5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/50nfwKoDiSYg8zOCREWAm5',
#   'duration_ms': 207853,
#   'time_signature': 4},
#  '3rmo8F54jFF8OgYsqTxm5d': {'danceability': 0.807,
#   'energy': 0.893,
#   'key': 11,
#   'loudness': -3.745,
#   'mode': 0,
#   'speechiness': 0.0347,
#   'acousticness': 0.0451,
#   'instrumentalness': 2.79e-05,
#   'liveness': 0.366,
#   'valence': 0.537,
#   'tempo': 126.011,
#   'type': 'audio_features',
#   'id': '3rmo8F54jFF8OgYsqTxm5d',
#   'uri': 'spotify:track:3rmo8F54jFF8OgYsqTxm5d',
#   'track_href': 'https://api.spotify.com/v1/tracks/3rmo8F54jFF8OgYsqTxm5d',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3rmo8F54jFF8OgYsqTxm5d',
#   'duration_ms': 230747,
#   'time_signature': 4},
#  '2QjOHCTQ1Jl3zawyYOpxh6': {'danceability': 0.612,
#   'energy': 0.807,
#   'key': 10,
#   'loudness': -2.81,
#   'mode': 1,
#   'speechiness': 0.0336,
#   'acousticness': 0.0495,
#   'instrumentalness': 0.0177,
#   'liveness': 0.101,
#   'valence': 0.398,
#   'tempo': 124.053,
#   'type': 'audio_features',
#   'id': '2QjOHCTQ1Jl3zawyYOpxh6',
#   'uri': 'spotify:track:2QjOHCTQ1Jl3zawyYOpxh6',
#   'track_href': 'https://api.spotify.com/v1/tracks/2QjOHCTQ1Jl3zawyYOpxh6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2QjOHCTQ1Jl3zawyYOpxh6',
#   'duration_ms': 240400,
#   'time_signature': 4},
#  '5CZ40GBx1sQ9agT82CLQCT': {'danceability': 0.38,
#   'energy': 0.339,
#   'key': 3,
#   'loudness': -7.885,
#   'mode': 1,
#   'speechiness': 0.0338,
#   'acousticness': 0.691,
#   'instrumentalness': 0,
#   'liveness': 0.12,
#   'valence': 0.0849,
#   'tempo': 100.607,
#   'type': 'audio_features',
#   'id': '5CZ40GBx1sQ9agT82CLQCT',
#   'uri': 'spotify:track:5CZ40GBx1sQ9agT82CLQCT',
#   'track_href': 'https://api.spotify.com/v1/tracks/5CZ40GBx1sQ9agT82CLQCT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5CZ40GBx1sQ9agT82CLQCT',
#   'duration_ms': 229227,
#   'time_signature': 4},
#  '07MDkzWARZaLEdKxo6yArG': {'danceability': 0.773,
#   'energy': 0.47,
#   'key': 2,
#   'loudness': -7.93,
#   'mode': 1,
#   'speechiness': 0.0299,
#   'acousticness': 0.0153,
#   'instrumentalness': 0.000193,
#   'liveness': 0.0851,
#   'valence': 0.399,
#   'tempo': 94.995,
#   'type': 'audio_features',
#   'id': '07MDkzWARZaLEdKxo6yArG',
#   'uri': 'spotify:track:07MDkzWARZaLEdKxo6yArG',
#   'track_href': 'https://api.spotify.com/v1/tracks/07MDkzWARZaLEdKxo6yArG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/07MDkzWARZaLEdKxo6yArG',
#   'duration_ms': 162680,
#   'time_signature': 4},
#  '4RVwu0g32PAqgUiJoXsdF8': {'danceability': 0.332,
#   'energy': 0.225,
#   'key': 0,
#   'loudness': -8.697,
#   'mode': 1,
#   'speechiness': 0.0348,
#   'acousticness': 0.767,
#   'instrumentalness': 0.00349,
#   'liveness': 0.128,
#   'valence': 0.297,
#   'tempo': 81.055,
#   'type': 'audio_features',
#   'id': '4RVwu0g32PAqgUiJoXsdF8',
#   'uri': 'spotify:track:4RVwu0g32PAqgUiJoXsdF8',
#   'track_href': 'https://api.spotify.com/v1/tracks/4RVwu0g32PAqgUiJoXsdF8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4RVwu0g32PAqgUiJoXsdF8',
#   'duration_ms': 298899,
#   'time_signature': 3},
#  '1BSMpVGWs3v5BZKnAQziAc': {'danceability': 0.69,
#   'energy': 0.626,
#   'key': 6,
#   'loudness': -5.693,
#   'mode': 1,
#   'speechiness': 0.306,
#   'acousticness': 0.105,
#   'instrumentalness': 0.000335,
#   'liveness': 0.0881,
#   'valence': 0.912,
#   'tempo': 184.009,
#   'type': 'audio_features',
#   'id': '1BSMpVGWs3v5BZKnAQziAc',
#   'uri': 'spotify:track:1BSMpVGWs3v5BZKnAQziAc',
#   'track_href': 'https://api.spotify.com/v1/tracks/1BSMpVGWs3v5BZKnAQziAc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1BSMpVGWs3v5BZKnAQziAc',
#   'duration_ms': 185681,
#   'time_signature': 4},
#  '1nH2PkJL1XoUq8oE6tBZoU': {'danceability': 0.735,
#   'energy': 0.795,
#   'key': 11,
#   'loudness': -6.523,
#   'mode': 0,
#   'speechiness': 0.113,
#   'acousticness': 0.0296,
#   'instrumentalness': 3.18e-05,
#   'liveness': 0.0678,
#   'valence': 0.905,
#   'tempo': 122.0,
#   'type': 'audio_features',
#   'id': '1nH2PkJL1XoUq8oE6tBZoU',
#   'uri': 'spotify:track:1nH2PkJL1XoUq8oE6tBZoU',
#   'track_href': 'https://api.spotify.com/v1/tracks/1nH2PkJL1XoUq8oE6tBZoU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1nH2PkJL1XoUq8oE6tBZoU',
#   'duration_ms': 188918,
#   'time_signature': 4},
#  '3Kkjo3cT83cw09VJyrLNwX': {'danceability': 0.534,
#   'energy': 0.725,
#   'key': 1,
#   'loudness': -3.906,
#   'mode': 1,
#   'speechiness': 0.046,
#   'acousticness': 0.091,
#   'instrumentalness': 0,
#   'liveness': 0.0264,
#   'valence': 0.55,
#   'tempo': 88.098,
#   'type': 'audio_features',
#   'id': '3Kkjo3cT83cw09VJyrLNwX',
#   'uri': 'spotify:track:3Kkjo3cT83cw09VJyrLNwX',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Kkjo3cT83cw09VJyrLNwX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Kkjo3cT83cw09VJyrLNwX',
#   'duration_ms': 225149,
#   'time_signature': 4},
#  '3GZD6HmiNUhxXYf8Gch723': {'danceability': 0.913,
#   'energy': 0.603,
#   'key': 8,
#   'loudness': -4.892,
#   'mode': 1,
#   'speechiness': 0.226,
#   'acousticness': 0.0272,
#   'instrumentalness': 0.000503,
#   'liveness': 0.167,
#   'valence': 0.497,
#   'tempo': 123.061,
#   'type': 'audio_features',
#   'id': '3GZD6HmiNUhxXYf8Gch723',
#   'uri': 'spotify:track:3GZD6HmiNUhxXYf8Gch723',
#   'track_href': 'https://api.spotify.com/v1/tracks/3GZD6HmiNUhxXYf8Gch723',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3GZD6HmiNUhxXYf8Gch723',
#   'duration_ms': 234093,
#   'time_signature': 4},
#  '0VjIjW4GlUZAMYd2vXMi3b': {'danceability': 0.514,
#   'energy': 0.73,
#   'key': 1,
#   'loudness': -5.934,
#   'mode': 1,
#   'speechiness': 0.0598,
#   'acousticness': 0.00146,
#   'instrumentalness': 9.54e-05,
#   'liveness': 0.0897,
#   'valence': 0.334,
#   'tempo': 171.005,
#   'type': 'audio_features',
#   'id': '0VjIjW4GlUZAMYd2vXMi3b',
#   'uri': 'spotify:track:0VjIjW4GlUZAMYd2vXMi3b',
#   'track_href': 'https://api.spotify.com/v1/tracks/0VjIjW4GlUZAMYd2vXMi3b',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VjIjW4GlUZAMYd2vXMi3b',
#   'duration_ms': 200040,
#   'time_signature': 4},
#  '0k4d5YPDr1r7FX77VdqWez': {'danceability': 0.828,
#   'energy': 0.621,
#   'key': 8,
#   'loudness': -6.414,
#   'mode': 1,
#   'speechiness': 0.0565,
#   'acousticness': 0.0164,
#   'instrumentalness': 0.00233,
#   'liveness': 0.0845,
#   'valence': 0.436,
#   'tempo': 128.986,
#   'type': 'audio_features',
#   'id': '0k4d5YPDr1r7FX77VdqWez',
#   'uri': 'spotify:track:0k4d5YPDr1r7FX77VdqWez',
#   'track_href': 'https://api.spotify.com/v1/tracks/0k4d5YPDr1r7FX77VdqWez',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0k4d5YPDr1r7FX77VdqWez',
#   'duration_ms': 186173,
#   'time_signature': 4},
#  '5enxwA8aAbwZbf5qCHORXi': {'danceability': 0.631,
#   'energy': 0.518,
#   'key': 0,
#   'loudness': -8.771,
#   'mode': 1,
#   'speechiness': 0.0303,
#   'acousticness': 0.274,
#   'instrumentalness': 0,
#   'liveness': 0.088,
#   'valence': 0.205,
#   'tempo': 93.023,
#   'type': 'audio_features',
#   'id': '5enxwA8aAbwZbf5qCHORXi',
#   'uri': 'spotify:track:5enxwA8aAbwZbf5qCHORXi',
#   'track_href': 'https://api.spotify.com/v1/tracks/5enxwA8aAbwZbf5qCHORXi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5enxwA8aAbwZbf5qCHORXi',
#   'duration_ms': 613027,
#   'time_signature': 4},
#  '1PNs0uGru3TcrA94kpyGnc': {'danceability': 0.842,
#   'energy': 0.505,
#   'key': 1,
#   'loudness': -8.627,
#   'mode': 0,
#   'speechiness': 0.402,
#   'acousticness': 0.472,
#   'instrumentalness': 0.000322,
#   'liveness': 0.117,
#   'valence': 0.538,
#   'tempo': 119.993,
#   'type': 'audio_features',
#   'id': '1PNs0uGru3TcrA94kpyGnc',
#   'uri': 'spotify:track:1PNs0uGru3TcrA94kpyGnc',
#   'track_href': 'https://api.spotify.com/v1/tracks/1PNs0uGru3TcrA94kpyGnc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1PNs0uGru3TcrA94kpyGnc',
#   'duration_ms': 207065,
#   'time_signature': 4},
#  '7H0ya83CMmgFcOhw0UB6ow': {'danceability': 0.508,
#   'energy': 0.792,
#   'key': 0,
#   'loudness': -7.311,
#   'mode': 0,
#   'speechiness': 0.0297,
#   'acousticness': 0.229,
#   'instrumentalness': 0.124,
#   'liveness': 0.145,
#   'valence': 0.601,
#   'tempo': 147.067,
#   'type': 'audio_features',
#   'id': '7H0ya83CMmgFcOhw0UB6ow',
#   'uri': 'spotify:track:7H0ya83CMmgFcOhw0UB6ow',
#   'track_href': 'https://api.spotify.com/v1/tracks/7H0ya83CMmgFcOhw0UB6ow',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7H0ya83CMmgFcOhw0UB6ow',
#   'duration_ms': 320467,
#   'time_signature': 4},
#  '0IuVhCflrQPMGRrOyoY5RW': {'danceability': 0.614,
#   'energy': 0.644,
#   'key': 2,
#   'loudness': -5.372,
#   'mode': 0,
#   'speechiness': 0.0426,
#   'acousticness': 0.0134,
#   'instrumentalness': 7.07e-06,
#   'liveness': 0.117,
#   'valence': 0.651,
#   'tempo': 160.036,
#   'type': 'audio_features',
#   'id': '0IuVhCflrQPMGRrOyoY5RW',
#   'uri': 'spotify:track:0IuVhCflrQPMGRrOyoY5RW',
#   'track_href': 'https://api.spotify.com/v1/tracks/0IuVhCflrQPMGRrOyoY5RW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0IuVhCflrQPMGRrOyoY5RW',
#   'duration_ms': 206772,
#   'time_signature': 4},
#  '6I3mqTwhRpn34SLVafSH7G': {'danceability': 0.601,
#   'energy': 0.741,
#   'key': 2,
#   'loudness': -5.569,
#   'mode': 1,
#   'speechiness': 0.0478,
#   'acousticness': 0.185,
#   'instrumentalness': 2.91e-05,
#   'liveness': 0.415,
#   'valence': 0.441,
#   'tempo': 153.96,
#   'type': 'audio_features',
#   'id': '6I3mqTwhRpn34SLVafSH7G',
#   'uri': 'spotify:track:6I3mqTwhRpn34SLVafSH7G',
#   'track_href': 'https://api.spotify.com/v1/tracks/6I3mqTwhRpn34SLVafSH7G',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6I3mqTwhRpn34SLVafSH7G',
#   'duration_ms': 153190,
#   'time_signature': 4},
#  '3xRH6FPVtheDyNla3T1FE7': {'danceability': 0.511,
#   'energy': 0.525,
#   'key': 8,
#   'loudness': -4.595,
#   'mode': 0,
#   'speechiness': 0.183,
#   'acousticness': 0.604,
#   'instrumentalness': 0,
#   'liveness': 0.111,
#   'valence': 0.661,
#   'tempo': 139.885,
#   'type': 'audio_features',
#   'id': '3xRH6FPVtheDyNla3T1FE7',
#   'uri': 'spotify:track:3xRH6FPVtheDyNla3T1FE7',
#   'track_href': 'https://api.spotify.com/v1/tracks/3xRH6FPVtheDyNla3T1FE7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3xRH6FPVtheDyNla3T1FE7',
#   'duration_ms': 204317,
#   'time_signature': 3},
#  '1SOClUWhOi8vHZYMz3GluK': {'danceability': 0.671,
#   'energy': 0.673,
#   'key': 11,
#   'loudness': -6.941,
#   'mode': 0,
#   'speechiness': 0.0444,
#   'acousticness': 0.148,
#   'instrumentalness': 5.29e-05,
#   'liveness': 0.304,
#   'valence': 0.494,
#   'tempo': 121.963,
#   'type': 'audio_features',
#   'id': '1SOClUWhOi8vHZYMz3GluK',
#   'uri': 'spotify:track:1SOClUWhOi8vHZYMz3GluK',
#   'track_href': 'https://api.spotify.com/v1/tracks/1SOClUWhOi8vHZYMz3GluK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1SOClUWhOi8vHZYMz3GluK',
#   'duration_ms': 237720,
#   'time_signature': 4},
#  '2vWBUC9djv6BtiGlmKiQaH': {'danceability': 0.372,
#   'energy': 0.537,
#   'key': 9,
#   'loudness': -7.623,
#   'mode': 1,
#   'speechiness': 0.0305,
#   'acousticness': 0.937,
#   'instrumentalness': 0.873,
#   'liveness': 0.287,
#   'valence': 0.228,
#   'tempo': 123.735,
#   'type': 'audio_features',
#   'id': '2vWBUC9djv6BtiGlmKiQaH',
#   'uri': 'spotify:track:2vWBUC9djv6BtiGlmKiQaH',
#   'track_href': 'https://api.spotify.com/v1/tracks/2vWBUC9djv6BtiGlmKiQaH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2vWBUC9djv6BtiGlmKiQaH',
#   'duration_ms': 212750,
#   'time_signature': 3},
#  '02MWAaffLxlfxAUY7c5dvx': {'danceability': 0.761,
#   'energy': 0.525,
#   'key': 11,
#   'loudness': -6.9,
#   'mode': 1,
#   'speechiness': 0.0944,
#   'acousticness': 0.44,
#   'instrumentalness': 6.7e-06,
#   'liveness': 0.0921,
#   'valence': 0.531,
#   'tempo': 80.87,
#   'type': 'audio_features',
#   'id': '02MWAaffLxlfxAUY7c5dvx',
#   'uri': 'spotify:track:02MWAaffLxlfxAUY7c5dvx',
#   'track_href': 'https://api.spotify.com/v1/tracks/02MWAaffLxlfxAUY7c5dvx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/02MWAaffLxlfxAUY7c5dvx',
#   'duration_ms': 238805,
#   'time_signature': 4},
#  '6HU7h9RYOaPRFeh0R3UeAr': {'danceability': 0.442,
#   'energy': 0.612,
#   'key': 2,
#   'loudness': -7.222,
#   'mode': 1,
#   'speechiness': 0.112,
#   'acousticness': 0.584,
#   'instrumentalness': 5.7e-06,
#   'liveness': 0.37,
#   'valence': 0.178,
#   'tempo': 180.917,
#   'type': 'audio_features',
#   'id': '6HU7h9RYOaPRFeh0R3UeAr',
#   'uri': 'spotify:track:6HU7h9RYOaPRFeh0R3UeAr',
#   'track_href': 'https://api.spotify.com/v1/tracks/6HU7h9RYOaPRFeh0R3UeAr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6HU7h9RYOaPRFeh0R3UeAr',
#   'duration_ms': 215507,
#   'time_signature': 4},
#  '5wANPM4fQCJwkGd4rN57mH': {'danceability': 0.561,
#   'energy': 0.431,
#   'key': 10,
#   'loudness': -8.81,
#   'mode': 1,
#   'speechiness': 0.0578,
#   'acousticness': 0.768,
#   'instrumentalness': 1.42e-05,
#   'liveness': 0.106,
#   'valence': 0.137,
#   'tempo': 143.875,
#   'type': 'audio_features',
#   'id': '5wANPM4fQCJwkGd4rN57mH',
#   'uri': 'spotify:track:5wANPM4fQCJwkGd4rN57mH',
#   'track_href': 'https://api.spotify.com/v1/tracks/5wANPM4fQCJwkGd4rN57mH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5wANPM4fQCJwkGd4rN57mH',
#   'duration_ms': 242013,
#   'time_signature': 4},
#  '748mdHapucXQri7IAO8yFK': {'danceability': 0.762,
#   'energy': 0.701,
#   'key': 8,
#   'loudness': -3.541,
#   'mode': 1,
#   'speechiness': 0.0286,
#   'acousticness': 0.235,
#   'instrumentalness': 0.000158,
#   'liveness': 0.123,
#   'valence': 0.742,
#   'tempo': 110.968,
#   'type': 'audio_features',
#   'id': '748mdHapucXQri7IAO8yFK',
#   'uri': 'spotify:track:748mdHapucXQri7IAO8yFK',
#   'track_href': 'https://api.spotify.com/v1/tracks/748mdHapucXQri7IAO8yFK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/748mdHapucXQri7IAO8yFK',
#   'duration_ms': 208867,
#   'time_signature': 4},
#  '2K7xn816oNHJZ0aVqdQsha': {'danceability': 0.575,
#   'energy': 0.568,
#   'key': 9,
#   'loudness': -5.509,
#   'mode': 0,
#   'speechiness': 0.03,
#   'acousticness': 0.0484,
#   'instrumentalness': 0.000417,
#   'liveness': 0.286,
#   'valence': 0.37,
#   'tempo': 93.986,
#   'type': 'audio_features',
#   'id': '2K7xn816oNHJZ0aVqdQsha',
#   'uri': 'spotify:track:2K7xn816oNHJZ0aVqdQsha',
#   'track_href': 'https://api.spotify.com/v1/tracks/2K7xn816oNHJZ0aVqdQsha',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2K7xn816oNHJZ0aVqdQsha',
#   'duration_ms': 206280,
#   'time_signature': 4},
#  '3YJJjQPAbDT7mGpX3WtQ9A': {'danceability': 0.436,
#   'energy': 0.655,
#   'key': 1,
#   'loudness': -8.37,
#   'mode': 0,
#   'speechiness': 0.0583,
#   'acousticness': 0.499,
#   'instrumentalness': 8.1e-06,
#   'liveness': 0.688,
#   'valence': 0.412,
#   'tempo': 121.002,
#   'type': 'audio_features',
#   'id': '3YJJjQPAbDT7mGpX3WtQ9A',
#   'uri': 'spotify:track:3YJJjQPAbDT7mGpX3WtQ9A',
#   'track_href': 'https://api.spotify.com/v1/tracks/3YJJjQPAbDT7mGpX3WtQ9A',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3YJJjQPAbDT7mGpX3WtQ9A',
#   'duration_ms': 279204,
#   'time_signature': 4},
#  '2eAvDnpXP5W0cVtiI0PUxV': {'danceability': 0.609,
#   'energy': 0.692,
#   'key': 1,
#   'loudness': -2.958,
#   'mode': 1,
#   'speechiness': 0.0259,
#   'acousticness': 0.0157,
#   'instrumentalness': 0,
#   'liveness': 0.0864,
#   'valence': 0.454,
#   'tempo': 116.959,
#   'type': 'audio_features',
#   'id': '2eAvDnpXP5W0cVtiI0PUxV',
#   'uri': 'spotify:track:2eAvDnpXP5W0cVtiI0PUxV',
#   'track_href': 'https://api.spotify.com/v1/tracks/2eAvDnpXP5W0cVtiI0PUxV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2eAvDnpXP5W0cVtiI0PUxV',
#   'duration_ms': 233720,
#   'time_signature': 3},
#  '60ynsPSSKe6O3sfwRnIBRf': {'danceability': 0.749,
#   'energy': 0.463,
#   'key': 11,
#   'loudness': -8.433,
#   'mode': 1,
#   'speechiness': 0.0842,
#   'acousticness': 0.21,
#   'instrumentalness': 0.0382,
#   'liveness': 0.338,
#   'valence': 0.189,
#   'tempo': 90.035,
#   'type': 'audio_features',
#   'id': '60ynsPSSKe6O3sfwRnIBRf',
#   'uri': 'spotify:track:60ynsPSSKe6O3sfwRnIBRf',
#   'track_href': 'https://api.spotify.com/v1/tracks/60ynsPSSKe6O3sfwRnIBRf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/60ynsPSSKe6O3sfwRnIBRf',
#   'duration_ms': 226987,
#   'time_signature': 4},
#  '10hMM5nsZQf66ldBlgWBfG': {'danceability': 0.348,
#   'energy': 0.652,
#   'key': 3,
#   'loudness': -7.145,
#   'mode': 1,
#   'speechiness': 0.0931,
#   'acousticness': 0.0165,
#   'instrumentalness': 0.000264,
#   'liveness': 0.33,
#   'valence': 0.172,
#   'tempo': 70.956,
#   'type': 'audio_features',
#   'id': '10hMM5nsZQf66ldBlgWBfG',
#   'uri': 'spotify:track:10hMM5nsZQf66ldBlgWBfG',
#   'track_href': 'https://api.spotify.com/v1/tracks/10hMM5nsZQf66ldBlgWBfG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/10hMM5nsZQf66ldBlgWBfG',
#   'duration_ms': 192987,
#   'time_signature': 4},
#  '0k1WUmIRnG3xU6fvvDVfRG': {'danceability': 0.803,
#   'energy': 0.597,
#   'key': 11,
#   'loudness': -6.035,
#   'mode': 0,
#   'speechiness': 0.141,
#   'acousticness': 0.000619,
#   'instrumentalness': 4.5e-06,
#   'liveness': 0.323,
#   'valence': 0.331,
#   'tempo': 136.008,
#   'type': 'audio_features',
#   'id': '0k1WUmIRnG3xU6fvvDVfRG',
#   'uri': 'spotify:track:0k1WUmIRnG3xU6fvvDVfRG',
#   'track_href': 'https://api.spotify.com/v1/tracks/0k1WUmIRnG3xU6fvvDVfRG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0k1WUmIRnG3xU6fvvDVfRG',
#   'duration_ms': 257605,
#   'time_signature': 4},
#  '6tDDoYIxWvMLTdKpjFkc1B': {'danceability': 0.653,
#   'energy': 0.524,
#   'key': 11,
#   'loudness': -9.016,
#   'mode': 0,
#   'speechiness': 0.0502,
#   'acousticness': 0.112,
#   'instrumentalness': 0,
#   'liveness': 0.203,
#   'valence': 0.553,
#   'tempo': 83.97,
#   'type': 'audio_features',
#   'id': '6tDDoYIxWvMLTdKpjFkc1B',
#   'uri': 'spotify:track:6tDDoYIxWvMLTdKpjFkc1B',
#   'track_href': 'https://api.spotify.com/v1/tracks/6tDDoYIxWvMLTdKpjFkc1B',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6tDDoYIxWvMLTdKpjFkc1B',
#   'duration_ms': 160191,
#   'time_signature': 4},
#  '4iN16F8JtVxG2UTzp3avGl': {'danceability': 0.627,
#   'energy': 0.618,
#   'key': 2,
#   'loudness': -8.529,
#   'mode': 1,
#   'speechiness': 0.0437,
#   'acousticness': 0.0558,
#   'instrumentalness': 0,
#   'liveness': 0.351,
#   'valence': 0.848,
#   'tempo': 82.03,
#   'type': 'audio_features',
#   'id': '4iN16F8JtVxG2UTzp3avGl',
#   'uri': 'spotify:track:4iN16F8JtVxG2UTzp3avGl',
#   'track_href': 'https://api.spotify.com/v1/tracks/4iN16F8JtVxG2UTzp3avGl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4iN16F8JtVxG2UTzp3avGl',
#   'duration_ms': 197443,
#   'time_signature': 4},
#  '4xqrdfXkTW4T0RauPLv3WA': {'danceability': 0.357,
#   'energy': 0.425,
#   'key': 5,
#   'loudness': -7.301,
#   'mode': 1,
#   'speechiness': 0.0333,
#   'acousticness': 0.584,
#   'instrumentalness': 0,
#   'liveness': 0.322,
#   'valence': 0.27,
#   'tempo': 102.078,
#   'type': 'audio_features',
#   'id': '4xqrdfXkTW4T0RauPLv3WA',
#   'uri': 'spotify:track:4xqrdfXkTW4T0RauPLv3WA',
#   'track_href': 'https://api.spotify.com/v1/tracks/4xqrdfXkTW4T0RauPLv3WA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4xqrdfXkTW4T0RauPLv3WA',
#   'duration_ms': 198040,
#   'time_signature': 3},
#  '37BZB0z9T8Xu7U3e65qxFy': {'danceability': 0.65,
#   'energy': 0.825,
#   'key': 0,
#   'loudness': -4.645,
#   'mode': 1,
#   'speechiness': 0.0325,
#   'acousticness': 0.0215,
#   'instrumentalness': 2.44e-05,
#   'liveness': 0.0936,
#   'valence': 0.593,
#   'tempo': 118.091,
#   'type': 'audio_features',
#   'id': '37BZB0z9T8Xu7U3e65qxFy',
#   'uri': 'spotify:track:37BZB0z9T8Xu7U3e65qxFy',
#   'track_href': 'https://api.spotify.com/v1/tracks/37BZB0z9T8Xu7U3e65qxFy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/37BZB0z9T8Xu7U3e65qxFy',
#   'duration_ms': 191014,
#   'time_signature': 4},
#  '0mL82sxCRjrs3br407IdJh': {'danceability': 0.702,
#   'energy': 0.586,
#   'key': 9,
#   'loudness': -7.83,
#   'mode': 0,
#   'speechiness': 0.0313,
#   'acousticness': 0.0388,
#   'instrumentalness': 7.27e-05,
#   'liveness': 0.156,
#   'valence': 0.608,
#   'tempo': 134.951,
#   'type': 'audio_features',
#   'id': '0mL82sxCRjrs3br407IdJh',
#   'uri': 'spotify:track:0mL82sxCRjrs3br407IdJh',
#   'track_href': 'https://api.spotify.com/v1/tracks/0mL82sxCRjrs3br407IdJh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0mL82sxCRjrs3br407IdJh',
#   'duration_ms': 199111,
#   'time_signature': 4},
#  '1BYZxKSf0aTxp8ZFoeyM3d': {'danceability': 0.566,
#   'energy': 0.366,
#   'key': 7,
#   'loudness': -12.808,
#   'mode': 1,
#   'speechiness': 0.028,
#   'acousticness': 0.113,
#   'instrumentalness': 0.181,
#   'liveness': 0.155,
#   'valence': 0.237,
#   'tempo': 129.959,
#   'type': 'audio_features',
#   'id': '1BYZxKSf0aTxp8ZFoeyM3d',
#   'uri': 'spotify:track:1BYZxKSf0aTxp8ZFoeyM3d',
#   'track_href': 'https://api.spotify.com/v1/tracks/1BYZxKSf0aTxp8ZFoeyM3d',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1BYZxKSf0aTxp8ZFoeyM3d',
#   'duration_ms': 184154,
#   'time_signature': 4},
#  '2SLwbpExuoBDZBpjfefCtV': {'danceability': 0.65,
#   'energy': 0.76,
#   'key': 0,
#   'loudness': -4.422,
#   'mode': 0,
#   'speechiness': 0.0446,
#   'acousticness': 0.255,
#   'instrumentalness': 0,
#   'liveness': 0.339,
#   'valence': 0.838,
#   'tempo': 93.057,
#   'type': 'audio_features',
#   'id': '2SLwbpExuoBDZBpjfefCtV',
#   'uri': 'spotify:track:2SLwbpExuoBDZBpjfefCtV',
#   'track_href': 'https://api.spotify.com/v1/tracks/2SLwbpExuoBDZBpjfefCtV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2SLwbpExuoBDZBpjfefCtV',
#   'duration_ms': 214194,
#   'time_signature': 4},
#  '6EtKlIQmGPB9SX8UjDJG5s': {'danceability': 0.574,
#   'energy': 0.664,
#   'key': 11,
#   'loudness': -6.068,
#   'mode': 1,
#   'speechiness': 0.0409,
#   'acousticness': 0.0448,
#   'instrumentalness': 0.0553,
#   'liveness': 0.146,
#   'valence': 0.226,
#   'tempo': 144.654,
#   'type': 'audio_features',
#   'id': '6EtKlIQmGPB9SX8UjDJG5s',
#   'uri': 'spotify:track:6EtKlIQmGPB9SX8UjDJG5s',
#   'track_href': 'https://api.spotify.com/v1/tracks/6EtKlIQmGPB9SX8UjDJG5s',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6EtKlIQmGPB9SX8UjDJG5s',
#   'duration_ms': 91870,
#   'time_signature': 4},
#  '5E30LdtzQTGqRvNd7l6kG5': {'danceability': 0.588,
#   'energy': 0.521,
#   'key': 10,
#   'loudness': -9.461,
#   'mode': 1,
#   'speechiness': 0.0329,
#   'acousticness': 0.0678,
#   'instrumentalness': 0.149,
#   'liveness': 0.123,
#   'valence': 0.337,
#   'tempo': 85.012,
#   'type': 'audio_features',
#   'id': '5E30LdtzQTGqRvNd7l6kG5',
#   'uri': 'spotify:track:5E30LdtzQTGqRvNd7l6kG5',
#   'track_href': 'https://api.spotify.com/v1/tracks/5E30LdtzQTGqRvNd7l6kG5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5E30LdtzQTGqRvNd7l6kG5',
#   'duration_ms': 260173,
#   'time_signature': 4},
#  '65OVbaJR5O1RmwOQx0875b': {'danceability': 0.578,
#   'energy': 0.449,
#   'key': 1,
#   'loudness': -6.349,
#   'mode': 1,
#   'speechiness': 0.286,
#   'acousticness': 0.0618,
#   'instrumentalness': 2.17e-06,
#   'liveness': 0.119,
#   'valence': 0.1,
#   'tempo': 136.006,
#   'type': 'audio_features',
#   'id': '65OVbaJR5O1RmwOQx0875b',
#   'uri': 'spotify:track:65OVbaJR5O1RmwOQx0875b',
#   'track_href': 'https://api.spotify.com/v1/tracks/65OVbaJR5O1RmwOQx0875b',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/65OVbaJR5O1RmwOQx0875b',
#   'duration_ms': 192956,
#   'time_signature': 4},
#  '0rKtyWc8bvkriBthvHKY8d': {'danceability': 0.515,
#   'energy': 0.479,
#   'key': 3,
#   'loudness': -7.458,
#   'mode': 1,
#   'speechiness': 0.0261,
#   'acousticness': 0.544,
#   'instrumentalness': 0.00598,
#   'liveness': 0.191,
#   'valence': 0.284,
#   'tempo': 88.964,
#   'type': 'audio_features',
#   'id': '0rKtyWc8bvkriBthvHKY8d',
#   'uri': 'spotify:track:0rKtyWc8bvkriBthvHKY8d',
#   'track_href': 'https://api.spotify.com/v1/tracks/0rKtyWc8bvkriBthvHKY8d',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0rKtyWc8bvkriBthvHKY8d',
#   'duration_ms': 209274,
#   'time_signature': 4},
#  '6EDO9iiTtwNv6waLwa1UUq': {'danceability': 0.8,
#   'energy': 0.56,
#   'key': 5,
#   'loudness': -4.818,
#   'mode': 0,
#   'speechiness': 0.261,
#   'acousticness': 0.057,
#   'instrumentalness': 0,
#   'liveness': 0.134,
#   'valence': 0.45,
#   'tempo': 163.071,
#   'type': 'audio_features',
#   'id': '6EDO9iiTtwNv6waLwa1UUq',
#   'uri': 'spotify:track:6EDO9iiTtwNv6waLwa1UUq',
#   'track_href': 'https://api.spotify.com/v1/tracks/6EDO9iiTtwNv6waLwa1UUq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6EDO9iiTtwNv6waLwa1UUq',
#   'duration_ms': 200221,
#   'time_signature': 4},
#  '6MO2bfLHKykUgCChFdw91H': {'danceability': 0.816,
#   'energy': 0.513,
#   'key': 1,
#   'loudness': -8.363,
#   'mode': 1,
#   'speechiness': 0.244,
#   'acousticness': 0.0145,
#   'instrumentalness': 0.000102,
#   'liveness': 0.14,
#   'valence': 0.17,
#   'tempo': 96.981,
#   'type': 'audio_features',
#   'id': '6MO2bfLHKykUgCChFdw91H',
#   'uri': 'spotify:track:6MO2bfLHKykUgCChFdw91H',
#   'track_href': 'https://api.spotify.com/v1/tracks/6MO2bfLHKykUgCChFdw91H',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6MO2bfLHKykUgCChFdw91H',
#   'duration_ms': 296011,
#   'time_signature': 4},
#  '2bx879t8gUpxkQ0avl8xTf': {'danceability': 0.566,
#   'energy': 0.976,
#   'key': 1,
#   'loudness': -3.866,
#   'mode': 1,
#   'speechiness': 0.262,
#   'acousticness': 0.000527,
#   'instrumentalness': 0.00265,
#   'liveness': 0.114,
#   'valence': 0.354,
#   'tempo': 193.979,
#   'type': 'audio_features',
#   'id': '2bx879t8gUpxkQ0avl8xTf',
#   'uri': 'spotify:track:2bx879t8gUpxkQ0avl8xTf',
#   'track_href': 'https://api.spotify.com/v1/tracks/2bx879t8gUpxkQ0avl8xTf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2bx879t8gUpxkQ0avl8xTf',
#   'duration_ms': 222360,
#   'time_signature': 4},
#  '6HZ9VeI5IRFCNQLXhpF4bq': {'danceability': 0.711,
#   'energy': 0.906,
#   'key': 8,
#   'loudness': -2.671,
#   'mode': 1,
#   'speechiness': 0.0284,
#   'acousticness': 0.00952,
#   'instrumentalness': 1.64e-05,
#   'liveness': 0.153,
#   'valence': 0.824,
#   'tempo': 125.916,
#   'type': 'audio_features',
#   'id': '6HZ9VeI5IRFCNQLXhpF4bq',
#   'uri': 'spotify:track:6HZ9VeI5IRFCNQLXhpF4bq',
#   'track_href': 'https://api.spotify.com/v1/tracks/6HZ9VeI5IRFCNQLXhpF4bq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6HZ9VeI5IRFCNQLXhpF4bq',
#   'duration_ms': 157153,
#   'time_signature': 4},
#  '2yAVzRiEQooPEJ9SYx11L3': {'danceability': 0.822,
#   'energy': 0.969,
#   'key': 7,
#   'loudness': -11.471,
#   'mode': 0,
#   'speechiness': 0.0582,
#   'acousticness': 0.259,
#   'instrumentalness': 0.000153,
#   'liveness': 0.39,
#   'valence': 0.765,
#   'tempo': 128.007,
#   'type': 'audio_features',
#   'id': '2yAVzRiEQooPEJ9SYx11L3',
#   'uri': 'spotify:track:2yAVzRiEQooPEJ9SYx11L3',
#   'track_href': 'https://api.spotify.com/v1/tracks/2yAVzRiEQooPEJ9SYx11L3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2yAVzRiEQooPEJ9SYx11L3',
#   'duration_ms': 283748,
#   'time_signature': 4},
#  '1sbEeUY8KsdvgiQi26JBFz': {'danceability': 0.803,
#   'energy': 0.565,
#   'key': 5,
#   'loudness': -4.711,
#   'mode': 0,
#   'speechiness': 0.235,
#   'acousticness': 0.0558,
#   'instrumentalness': 0,
#   'liveness': 0.141,
#   'valence': 0.474,
#   'tempo': 163.085,
#   'type': 'audio_features',
#   'id': '1sbEeUY8KsdvgiQi26JBFz',
#   'uri': 'spotify:track:1sbEeUY8KsdvgiQi26JBFz',
#   'track_href': 'https://api.spotify.com/v1/tracks/1sbEeUY8KsdvgiQi26JBFz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1sbEeUY8KsdvgiQi26JBFz',
#   'duration_ms': 200221,
#   'time_signature': 4},
#  '6SdKlwL3RgcTNRdyKLVSsO': {'danceability': 0.727,
#   'energy': 0.832,
#   'key': 9,
#   'loudness': -4.327,
#   'mode': 0,
#   'speechiness': 0.0366,
#   'acousticness': 0.181,
#   'instrumentalness': 0,
#   'liveness': 0.0615,
#   'valence': 0.213,
#   'tempo': 127.035,
#   'type': 'audio_features',
#   'id': '6SdKlwL3RgcTNRdyKLVSsO',
#   'uri': 'spotify:track:6SdKlwL3RgcTNRdyKLVSsO',
#   'track_href': 'https://api.spotify.com/v1/tracks/6SdKlwL3RgcTNRdyKLVSsO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6SdKlwL3RgcTNRdyKLVSsO',
#   'duration_ms': 177856,
#   'time_signature': 4},
#  '08SdUkfvfDjCcMhIkoOjCB': {'danceability': 0.774,
#   'energy': 0.792,
#   'key': 10,
#   'loudness': -4.021,
#   'mode': 1,
#   'speechiness': 0.0523,
#   'acousticness': 0.051,
#   'instrumentalness': 0,
#   'liveness': 0.155,
#   'valence': 0.507,
#   'tempo': 122.062,
#   'type': 'audio_features',
#   'id': '08SdUkfvfDjCcMhIkoOjCB',
#   'uri': 'spotify:track:08SdUkfvfDjCcMhIkoOjCB',
#   'track_href': 'https://api.spotify.com/v1/tracks/08SdUkfvfDjCcMhIkoOjCB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/08SdUkfvfDjCcMhIkoOjCB',
#   'duration_ms': 139672,
#   'time_signature': 4},
#  '7ltKdSawrH4syMjMhwVatI': {'danceability': 0.566,
#   'energy': 0.666,
#   'key': 5,
#   'loudness': -5.742,
#   'mode': 0,
#   'speechiness': 0.163,
#   'acousticness': 0.0164,
#   'instrumentalness': 1.99e-05,
#   'liveness': 0.229,
#   'valence': 0.394,
#   'tempo': 122.009,
#   'type': 'audio_features',
#   'id': '7ltKdSawrH4syMjMhwVatI',
#   'uri': 'spotify:track:7ltKdSawrH4syMjMhwVatI',
#   'track_href': 'https://api.spotify.com/v1/tracks/7ltKdSawrH4syMjMhwVatI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ltKdSawrH4syMjMhwVatI',
#   'duration_ms': 177727,
#   'time_signature': 5},
#  '5FXn5JHL50tDPMITGun9zh': {'danceability': 0.886,
#   'energy': 0.893,
#   'key': 6,
#   'loudness': -2.713,
#   'mode': 0,
#   'speechiness': 0.0612,
#   'acousticness': 0.116,
#   'instrumentalness': 0.0737,
#   'liveness': 0.145,
#   'valence': 0.814,
#   'tempo': 116.01,
#   'type': 'audio_features',
#   'id': '5FXn5JHL50tDPMITGun9zh',
#   'uri': 'spotify:track:5FXn5JHL50tDPMITGun9zh',
#   'track_href': 'https://api.spotify.com/v1/tracks/5FXn5JHL50tDPMITGun9zh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5FXn5JHL50tDPMITGun9zh',
#   'duration_ms': 145272,
#   'time_signature': 4},
#  '7MZ3AS7yg4pGUlA0JQhWXW': {'danceability': 0.559,
#   'energy': 0.381,
#   'key': 4,
#   'loudness': -8.54,
#   'mode': 1,
#   'speechiness': 0.0355,
#   'acousticness': 0.76,
#   'instrumentalness': 0,
#   'liveness': 0.0775,
#   'valence': 0.224,
#   'tempo': 119.116,
#   'type': 'audio_features',
#   'id': '7MZ3AS7yg4pGUlA0JQhWXW',
#   'uri': 'spotify:track:7MZ3AS7yg4pGUlA0JQhWXW',
#   'track_href': 'https://api.spotify.com/v1/tracks/7MZ3AS7yg4pGUlA0JQhWXW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7MZ3AS7yg4pGUlA0JQhWXW',
#   'duration_ms': 206453,
#   'time_signature': 3},
#  '2eKFa10K8Hu1VCTLm3DUkO': {'danceability': 0.915,
#   'energy': 0.705,
#   'key': 11,
#   'loudness': -3.724,
#   'mode': 1,
#   'speechiness': 0.125,
#   'acousticness': 0.00323,
#   'instrumentalness': 0.0228,
#   'liveness': 0.0621,
#   'valence': 0.958,
#   'tempo': 132.052,
#   'type': 'audio_features',
#   'id': '2eKFa10K8Hu1VCTLm3DUkO',
#   'uri': 'spotify:track:2eKFa10K8Hu1VCTLm3DUkO',
#   'track_href': 'https://api.spotify.com/v1/tracks/2eKFa10K8Hu1VCTLm3DUkO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2eKFa10K8Hu1VCTLm3DUkO',
#   'duration_ms': 140000,
#   'time_signature': 4},
#  '3QcWzAQvI41KYheHtvsNoT': {'danceability': 0.848,
#   'energy': 0.536,
#   'key': 0,
#   'loudness': -4.415,
#   'mode': 1,
#   'speechiness': 0.105,
#   'acousticness': 0.000235,
#   'instrumentalness': 0.015,
#   'liveness': 0.44,
#   'valence': 0.624,
#   'tempo': 111.964,
#   'type': 'audio_features',
#   'id': '3QcWzAQvI41KYheHtvsNoT',
#   'uri': 'spotify:track:3QcWzAQvI41KYheHtvsNoT',
#   'track_href': 'https://api.spotify.com/v1/tracks/3QcWzAQvI41KYheHtvsNoT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3QcWzAQvI41KYheHtvsNoT',
#   'duration_ms': 124286,
#   'time_signature': 4},
#  '0je6JQMhrkDF8aPSHcQ1r2': {'danceability': 0.556,
#   'energy': 0.834,
#   'key': 1,
#   'loudness': -5.016,
#   'mode': 1,
#   'speechiness': 0.055,
#   'acousticness': 0.00355,
#   'instrumentalness': 0.000185,
#   'liveness': 0.111,
#   'valence': 0.509,
#   'tempo': 90.042,
#   'type': 'audio_features',
#   'id': '0je6JQMhrkDF8aPSHcQ1r2',
#   'uri': 'spotify:track:0je6JQMhrkDF8aPSHcQ1r2',
#   'track_href': 'https://api.spotify.com/v1/tracks/0je6JQMhrkDF8aPSHcQ1r2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0je6JQMhrkDF8aPSHcQ1r2',
#   'duration_ms': 221499,
#   'time_signature': 4},
#  '2pFvmyLZsDDIptsHuF84N4': {'danceability': 0.877,
#   'energy': 0.825,
#   'key': 7,
#   'loudness': -2.736,
#   'mode': 1,
#   'speechiness': 0.142,
#   'acousticness': 0.00237,
#   'instrumentalness': 0.0331,
#   'liveness': 0.105,
#   'valence': 0.634,
#   'tempo': 130.061,
#   'type': 'audio_features',
#   'id': '2pFvmyLZsDDIptsHuF84N4',
#   'uri': 'spotify:track:2pFvmyLZsDDIptsHuF84N4',
#   'track_href': 'https://api.spotify.com/v1/tracks/2pFvmyLZsDDIptsHuF84N4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2pFvmyLZsDDIptsHuF84N4',
#   'duration_ms': 127385,
#   'time_signature': 4},
#  '1HHnQYqcnlnE9q7LGFFGFj': {'danceability': 0.798,
#   'energy': 0.752,
#   'key': 1,
#   'loudness': -5.947,
#   'mode': 1,
#   'speechiness': 0.227,
#   'acousticness': 0.128,
#   'instrumentalness': 0.0362,
#   'liveness': 0.0795,
#   'valence': 0.565,
#   'tempo': 125.996,
#   'type': 'audio_features',
#   'id': '1HHnQYqcnlnE9q7LGFFGFj',
#   'uri': 'spotify:track:1HHnQYqcnlnE9q7LGFFGFj',
#   'track_href': 'https://api.spotify.com/v1/tracks/1HHnQYqcnlnE9q7LGFFGFj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1HHnQYqcnlnE9q7LGFFGFj',
#   'duration_ms': 164740,
#   'time_signature': 4},
#  '3qGHAKgjQruzj6doKkyEb5': {'danceability': 0.504,
#   'energy': 0.711,
#   'key': 9,
#   'loudness': -5.864,
#   'mode': 1,
#   'speechiness': 0.0452,
#   'acousticness': 0.0585,
#   'instrumentalness': 1.83e-05,
#   'liveness': 0.382,
#   'valence': 0.5,
#   'tempo': 134.824,
#   'type': 'audio_features',
#   'id': '3qGHAKgjQruzj6doKkyEb5',
#   'uri': 'spotify:track:3qGHAKgjQruzj6doKkyEb5',
#   'track_href': 'https://api.spotify.com/v1/tracks/3qGHAKgjQruzj6doKkyEb5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3qGHAKgjQruzj6doKkyEb5',
#   'duration_ms': 232933,
#   'time_signature': 4},
#  '6dkNKTw0Fp92MrBCjPz9P7': {'danceability': 0.572,
#   'energy': 0.759,
#   'key': 2,
#   'loudness': -4.312,
#   'mode': 1,
#   'speechiness': 0.0506,
#   'acousticness': 0.127,
#   'instrumentalness': 0,
#   'liveness': 0.224,
#   'valence': 0.519,
#   'tempo': 80.95,
#   'type': 'audio_features',
#   'id': '6dkNKTw0Fp92MrBCjPz9P7',
#   'uri': 'spotify:track:6dkNKTw0Fp92MrBCjPz9P7',
#   'track_href': 'https://api.spotify.com/v1/tracks/6dkNKTw0Fp92MrBCjPz9P7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6dkNKTw0Fp92MrBCjPz9P7',
#   'duration_ms': 163733,
#   'time_signature': 4},
#  '2v19aHCMQEF9QTLahv8T72': {'danceability': 0.686,
#   'energy': 0.856,
#   'key': 9,
#   'loudness': -2.717,
#   'mode': 0,
#   'speechiness': 0.0426,
#   'acousticness': 0.0896,
#   'instrumentalness': 0,
#   'liveness': 0.0648,
#   'valence': 0.733,
#   'tempo': 123.997,
#   'type': 'audio_features',
#   'id': '2v19aHCMQEF9QTLahv8T72',
#   'uri': 'spotify:track:2v19aHCMQEF9QTLahv8T72',
#   'track_href': 'https://api.spotify.com/v1/tracks/2v19aHCMQEF9QTLahv8T72',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2v19aHCMQEF9QTLahv8T72',
#   'duration_ms': 181728,
#   'time_signature': 4},
#  '4W7RbZFvv6TMhPrEHDk22o': {'danceability': 0.686,
#   'energy': 0.856,
#   'key': 9,
#   'loudness': -2.717,
#   'mode': 0,
#   'speechiness': 0.0426,
#   'acousticness': 0.0896,
#   'instrumentalness': 0,
#   'liveness': 0.0648,
#   'valence': 0.733,
#   'tempo': 123.997,
#   'type': 'audio_features',
#   'id': '4W7RbZFvv6TMhPrEHDk22o',
#   'uri': 'spotify:track:4W7RbZFvv6TMhPrEHDk22o',
#   'track_href': 'https://api.spotify.com/v1/tracks/4W7RbZFvv6TMhPrEHDk22o',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4W7RbZFvv6TMhPrEHDk22o',
#   'duration_ms': 181728,
#   'time_signature': 4},
#  '4f0xlBAXHCY99SvS6yyR8p': {'danceability': 0.76,
#   'energy': 0.868,
#   'key': 4,
#   'loudness': -4.269,
#   'mode': 1,
#   'speechiness': 0.0489,
#   'acousticness': 0.131,
#   'instrumentalness': 1.7e-05,
#   'liveness': 0.226,
#   'valence': 0.704,
#   'tempo': 117.962,
#   'type': 'audio_features',
#   'id': '4f0xlBAXHCY99SvS6yyR8p',
#   'uri': 'spotify:track:4f0xlBAXHCY99SvS6yyR8p',
#   'track_href': 'https://api.spotify.com/v1/tracks/4f0xlBAXHCY99SvS6yyR8p',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4f0xlBAXHCY99SvS6yyR8p',
#   'duration_ms': 183078,
#   'time_signature': 4},
#  '6sVNcF3WDoXXVlRjRtRo9U': {'danceability': 0.659,
#   'energy': 0.877,
#   'key': 11,
#   'loudness': -5.089,
#   'mode': 0,
#   'speechiness': 0.0288,
#   'acousticness': 0.0878,
#   'instrumentalness': 0,
#   'liveness': 0.094,
#   'valence': 0.471,
#   'tempo': 119.992,
#   'type': 'audio_features',
#   'id': '6sVNcF3WDoXXVlRjRtRo9U',
#   'uri': 'spotify:track:6sVNcF3WDoXXVlRjRtRo9U',
#   'track_href': 'https://api.spotify.com/v1/tracks/6sVNcF3WDoXXVlRjRtRo9U',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6sVNcF3WDoXXVlRjRtRo9U',
#   'duration_ms': 160871,
#   'time_signature': 4},
#  '1DcN8xcU58uJoEofgDECIT': {'danceability': 0.659,
#   'energy': 0.877,
#   'key': 11,
#   'loudness': -5.089,
#   'mode': 0,
#   'speechiness': 0.0288,
#   'acousticness': 0.0878,
#   'instrumentalness': 0,
#   'liveness': 0.094,
#   'valence': 0.471,
#   'tempo': 119.992,
#   'type': 'audio_features',
#   'id': '1DcN8xcU58uJoEofgDECIT',
#   'uri': 'spotify:track:1DcN8xcU58uJoEofgDECIT',
#   'track_href': 'https://api.spotify.com/v1/tracks/1DcN8xcU58uJoEofgDECIT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1DcN8xcU58uJoEofgDECIT',
#   'duration_ms': 160871,
#   'time_signature': 4},
#  '24SDeYAeTFda8OUzVI1VR6': {'danceability': 0.571,
#   'energy': 0.747,
#   'key': 7,
#   'loudness': -4.659,
#   'mode': 1,
#   'speechiness': 0.17,
#   'acousticness': 0.478,
#   'instrumentalness': 0,
#   'liveness': 0.116,
#   'valence': 0.635,
#   'tempo': 106.253,
#   'type': 'audio_features',
#   'id': '24SDeYAeTFda8OUzVI1VR6',
#   'uri': 'spotify:track:24SDeYAeTFda8OUzVI1VR6',
#   'track_href': 'https://api.spotify.com/v1/tracks/24SDeYAeTFda8OUzVI1VR6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/24SDeYAeTFda8OUzVI1VR6',
#   'duration_ms': 259651,
#   'time_signature': 4},
#  '64A9jdEvQIL5cZAaqapIFL': {'danceability': 0.774,
#   'energy': 0.682,
#   'key': 5,
#   'loudness': -6.995,
#   'mode': 0,
#   'speechiness': 0.0489,
#   'acousticness': 0.00595,
#   'instrumentalness': 0.0376,
#   'liveness': 0.064,
#   'valence': 0.536,
#   'tempo': 129.987,
#   'type': 'audio_features',
#   'id': '64A9jdEvQIL5cZAaqapIFL',
#   'uri': 'spotify:track:64A9jdEvQIL5cZAaqapIFL',
#   'track_href': 'https://api.spotify.com/v1/tracks/64A9jdEvQIL5cZAaqapIFL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/64A9jdEvQIL5cZAaqapIFL',
#   'duration_ms': 174383,
#   'time_signature': 4},
#  '0Jc8qF1mUPo1A96HE9QxZz': {'danceability': 0.706,
#   'energy': 0.861,
#   'key': 11,
#   'loudness': -6.684,
#   'mode': 1,
#   'speechiness': 0.154,
#   'acousticness': 0.0341,
#   'instrumentalness': 0,
#   'liveness': 0.127,
#   'valence': 0.923,
#   'tempo': 119.946,
#   'type': 'audio_features',
#   'id': '0Jc8qF1mUPo1A96HE9QxZz',
#   'uri': 'spotify:track:0Jc8qF1mUPo1A96HE9QxZz',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Jc8qF1mUPo1A96HE9QxZz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Jc8qF1mUPo1A96HE9QxZz',
#   'duration_ms': 238427,
#   'time_signature': 4},
#  '2U9GEOiBLFwfPDZnHiXmDF': {'danceability': 0.769,
#   'energy': 0.43,
#   'key': 4,
#   'loudness': -14.231,
#   'mode': 0,
#   'speechiness': 0.0611,
#   'acousticness': 0.0373,
#   'instrumentalness': 0.22,
#   'liveness': 0.142,
#   'valence': 0.417,
#   'tempo': 99.998,
#   'type': 'audio_features',
#   'id': '2U9GEOiBLFwfPDZnHiXmDF',
#   'uri': 'spotify:track:2U9GEOiBLFwfPDZnHiXmDF',
#   'track_href': 'https://api.spotify.com/v1/tracks/2U9GEOiBLFwfPDZnHiXmDF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2U9GEOiBLFwfPDZnHiXmDF',
#   'duration_ms': 208798,
#   'time_signature': 4},
#  '0S69tBnqfjfqyQ03SnTEpI': {'danceability': 0.661,
#   'energy': 0.424,
#   'key': 0,
#   'loudness': -6.692,
#   'mode': 0,
#   'speechiness': 0.0297,
#   'acousticness': 0.736,
#   'instrumentalness': 0,
#   'liveness': 0.148,
#   'valence': 0.561,
#   'tempo': 117.03,
#   'type': 'audio_features',
#   'id': '0S69tBnqfjfqyQ03SnTEpI',
#   'uri': 'spotify:track:0S69tBnqfjfqyQ03SnTEpI',
#   'track_href': 'https://api.spotify.com/v1/tracks/0S69tBnqfjfqyQ03SnTEpI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0S69tBnqfjfqyQ03SnTEpI',
#   'duration_ms': 217653,
#   'time_signature': 4},
#  '0yssYGlua49rZDe8TCN5sJ': {'danceability': 0.754,
#   'energy': 0.681,
#   'key': 11,
#   'loudness': -6.332,
#   'mode': 1,
#   'speechiness': 0.0753,
#   'acousticness': 0.089,
#   'instrumentalness': 0.00103,
#   'liveness': 0.131,
#   'valence': 0.443,
#   'tempo': 130.013,
#   'type': 'audio_features',
#   'id': '0yssYGlua49rZDe8TCN5sJ',
#   'uri': 'spotify:track:0yssYGlua49rZDe8TCN5sJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/0yssYGlua49rZDe8TCN5sJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0yssYGlua49rZDe8TCN5sJ',
#   'duration_ms': 230920,
#   'time_signature': 4},
#  '0vswnzoKvhNkT1ehc0Tt19': {'danceability': 0.46,
#   'energy': 0.505,
#   'key': 9,
#   'loudness': -5.487,
#   'mode': 1,
#   'speechiness': 0.0266,
#   'acousticness': 0.42,
#   'instrumentalness': 0,
#   'liveness': 0.134,
#   'valence': 0.22,
#   'tempo': 135.757,
#   'type': 'audio_features',
#   'id': '0vswnzoKvhNkT1ehc0Tt19',
#   'uri': 'spotify:track:0vswnzoKvhNkT1ehc0Tt19',
#   'track_href': 'https://api.spotify.com/v1/tracks/0vswnzoKvhNkT1ehc0Tt19',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0vswnzoKvhNkT1ehc0Tt19',
#   'duration_ms': 235107,
#   'time_signature': 4},
#  '1kBxBS8M2e9cHwSs6PDve3': {'danceability': 0.764,
#   'energy': 0.672,
#   'key': 7,
#   'loudness': -5.947,
#   'mode': 0,
#   'speechiness': 0.0293,
#   'acousticness': 0.072,
#   'instrumentalness': 3.32e-06,
#   'liveness': 0.0806,
#   'valence': 0.789,
#   'tempo': 129.049,
#   'type': 'audio_features',
#   'id': '1kBxBS8M2e9cHwSs6PDve3',
#   'uri': 'spotify:track:1kBxBS8M2e9cHwSs6PDve3',
#   'track_href': 'https://api.spotify.com/v1/tracks/1kBxBS8M2e9cHwSs6PDve3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1kBxBS8M2e9cHwSs6PDve3',
#   'duration_ms': 136614,
#   'time_signature': 4},
#  '5KM8rXdxYIkBratm4QVIJR': {'danceability': 0.725,
#   'energy': 0.794,
#   'key': 7,
#   'loudness': -2.421,
#   'mode': 0,
#   'speechiness': 0.0699,
#   'acousticness': 0.305,
#   'instrumentalness': 0,
#   'liveness': 0.106,
#   'valence': 0.754,
#   'tempo': 123.964,
#   'type': 'audio_features',
#   'id': '5KM8rXdxYIkBratm4QVIJR',
#   'uri': 'spotify:track:5KM8rXdxYIkBratm4QVIJR',
#   'track_href': 'https://api.spotify.com/v1/tracks/5KM8rXdxYIkBratm4QVIJR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5KM8rXdxYIkBratm4QVIJR',
#   'duration_ms': 214560,
#   'time_signature': 4},
#  '24N35lPoI8qgHbaD8GReic': {'danceability': 0.764,
#   'energy': 0.672,
#   'key': 7,
#   'loudness': -5.947,
#   'mode': 0,
#   'speechiness': 0.0293,
#   'acousticness': 0.072,
#   'instrumentalness': 3.32e-06,
#   'liveness': 0.0806,
#   'valence': 0.789,
#   'tempo': 129.049,
#   'type': 'audio_features',
#   'id': '24N35lPoI8qgHbaD8GReic',
#   'uri': 'spotify:track:24N35lPoI8qgHbaD8GReic',
#   'track_href': 'https://api.spotify.com/v1/tracks/24N35lPoI8qgHbaD8GReic',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/24N35lPoI8qgHbaD8GReic',
#   'duration_ms': 136614,
# ...
#   'liveness': 0.277,
#   'valence': 0.959,
#   'tempo': 145.1,
#   'type': 'audio_features',
#   'id': '4HwQuM4s5ZtsFcTo9MumnW',
#   'uri': 'spotify:track:4HwQuM4s5ZtsFcTo9MumnW',
#   'track_href': 'https://api.spotify.com/v1/tracks/4HwQuM4s5ZtsFcTo9MumnW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4HwQuM4s5ZtsFcTo9MumnW',
#   'duration_ms': 211058,
#   'time_signature': 4},
#  '5pNRWjHiy0vOfupitU7pGU': {'danceability': 0.792,
#   'energy': 0.828,
#   'key': 6,
#   'loudness': -5.705,
#   'mode': 0,
#   'speechiness': 0.0661,
#   'acousticness': 0.484,
#   'instrumentalness': 0,
#   'liveness': 0.111,
#   'valence': 0.919,
#   'tempo': 109.939,
#   'type': 'audio_features',
#   'id': '5pNRWjHiy0vOfupitU7pGU',
#   'uri': 'spotify:track:5pNRWjHiy0vOfupitU7pGU',
#   'track_href': 'https://api.spotify.com/v1/tracks/5pNRWjHiy0vOfupitU7pGU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5pNRWjHiy0vOfupitU7pGU',
#   'duration_ms': 249373,
#   'time_signature': 1},
#  '5uTPstkP1Ljt3MzP0LE3uw': {'danceability': 0.541,
#   'energy': 0.353,
#   'key': 9,
#   'loudness': -5.519,
#   'mode': 0,
#   'speechiness': 0.0247,
#   'acousticness': 0.0818,
#   'instrumentalness': 6.83e-06,
#   'liveness': 0.126,
#   'valence': 0.27,
#   'tempo': 96.191,
#   'type': 'audio_features',
#   'id': '5uTPstkP1Ljt3MzP0LE3uw',
#   'uri': 'spotify:track:5uTPstkP1Ljt3MzP0LE3uw',
#   'track_href': 'https://api.spotify.com/v1/tracks/5uTPstkP1Ljt3MzP0LE3uw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5uTPstkP1Ljt3MzP0LE3uw',
#   'duration_ms': 235813,
#   'time_signature': 3},
#  '4nkMHa8OAlBtSO1clxQqTm': {'danceability': 0.813,
#   'energy': 0.875,
#   'key': 5,
#   'loudness': -4.39,
#   'mode': 1,
#   'speechiness': 0.0364,
#   'acousticness': 0.588,
#   'instrumentalness': 1.53e-05,
#   'liveness': 0.304,
#   'valence': 0.975,
#   'tempo': 135.039,
#   'type': 'audio_features',
#   'id': '4nkMHa8OAlBtSO1clxQqTm',
#   'uri': 'spotify:track:4nkMHa8OAlBtSO1clxQqTm',
#   'track_href': 'https://api.spotify.com/v1/tracks/4nkMHa8OAlBtSO1clxQqTm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4nkMHa8OAlBtSO1clxQqTm',
#   'duration_ms': 171549,
#   'time_signature': 4},
#  '5jAsabn1eV4jOAPjaSwSfm': {'danceability': 0.383,
#   'energy': 0.164,
#   'key': 5,
#   'loudness': -7.307,
#   'mode': 1,
#   'speechiness': 0.0386,
#   'acousticness': 0.481,
#   'instrumentalness': 1.55e-06,
#   'liveness': 0.299,
#   'valence': 0.37,
#   'tempo': 69.548,
#   'type': 'audio_features',
#   'id': '5jAsabn1eV4jOAPjaSwSfm',
#   'uri': 'spotify:track:5jAsabn1eV4jOAPjaSwSfm',
#   'track_href': 'https://api.spotify.com/v1/tracks/5jAsabn1eV4jOAPjaSwSfm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5jAsabn1eV4jOAPjaSwSfm',
#   'duration_ms': 191373,
#   'time_signature': 3},
#  '2sPKpLQFem7ScAbUQDAzeh': {'danceability': 0.578,
#   'energy': 0.333,
#   'key': 7,
#   'loudness': -4.382,
#   'mode': 1,
#   'speechiness': 0.0272,
#   'acousticness': 0.108,
#   'instrumentalness': 0,
#   'liveness': 0.27,
#   'valence': 0.365,
#   'tempo': 134.173,
#   'type': 'audio_features',
#   'id': '2sPKpLQFem7ScAbUQDAzeh',
#   'uri': 'spotify:track:2sPKpLQFem7ScAbUQDAzeh',
#   'track_href': 'https://api.spotify.com/v1/tracks/2sPKpLQFem7ScAbUQDAzeh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2sPKpLQFem7ScAbUQDAzeh',
#   'duration_ms': 209184,
#   'time_signature': 3},
#  '4GTbtRKeOTMoQ1OJyXKQpU': {'danceability': 0.787,
#   'energy': 0.47,
#   'key': 9,
#   'loudness': -5.724,
#   'mode': 1,
#   'speechiness': 0.0315,
#   'acousticness': 0.0253,
#   'instrumentalness': 0.000356,
#   'liveness': 0.12,
#   'valence': 0.379,
#   'tempo': 121.032,
#   'type': 'audio_features',
#   'id': '4GTbtRKeOTMoQ1OJyXKQpU',
#   'uri': 'spotify:track:4GTbtRKeOTMoQ1OJyXKQpU',
#   'track_href': 'https://api.spotify.com/v1/tracks/4GTbtRKeOTMoQ1OJyXKQpU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4GTbtRKeOTMoQ1OJyXKQpU',
#   'duration_ms': 170685,
#   'time_signature': 4},
#  '2MN2BpDJh8UsxCd7tpP7d5': {'danceability': 0.76,
#   'energy': 0.539,
#   'key': 11,
#   'loudness': -4.955,
#   'mode': 0,
#   'speechiness': 0.0249,
#   'acousticness': 0.131,
#   'instrumentalness': 0.000426,
#   'liveness': 0.0572,
#   'valence': 0.826,
#   'tempo': 96.059,
#   'type': 'audio_features',
#   'id': '2MN2BpDJh8UsxCd7tpP7d5',
#   'uri': 'spotify:track:2MN2BpDJh8UsxCd7tpP7d5',
#   'track_href': 'https://api.spotify.com/v1/tracks/2MN2BpDJh8UsxCd7tpP7d5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2MN2BpDJh8UsxCd7tpP7d5',
#   'duration_ms': 167573,
#   'time_signature': 4},
#  '35vWB9Yj2WwxpuI2WceZ38': {'danceability': 0.53,
#   'energy': 0.479,
#   'key': 2,
#   'loudness': -4.813,
#   'mode': 1,
#   'speechiness': 0.0281,
#   'acousticness': 0.37,
#   'instrumentalness': 0,
#   'liveness': 0.242,
#   'valence': 0.455,
#   'tempo': 143.966,
#   'type': 'audio_features',
#   'id': '35vWB9Yj2WwxpuI2WceZ38',
#   'uri': 'spotify:track:35vWB9Yj2WwxpuI2WceZ38',
#   'track_href': 'https://api.spotify.com/v1/tracks/35vWB9Yj2WwxpuI2WceZ38',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/35vWB9Yj2WwxpuI2WceZ38',
#   'duration_ms': 206384,
#   'time_signature': 4},
#  '1mN0VG09xkwIDUE4d7YtpG': {'danceability': 0.489,
#   'energy': 0.791,
#   'key': 9,
#   'loudness': -7.788,
#   'mode': 1,
#   'speechiness': 0.0462,
#   'acousticness': 0.399,
#   'instrumentalness': 9.72e-06,
#   'liveness': 0.191,
#   'valence': 0.945,
#   'tempo': 170.917,
#   'type': 'audio_features',
#   'id': '1mN0VG09xkwIDUE4d7YtpG',
#   'uri': 'spotify:track:1mN0VG09xkwIDUE4d7YtpG',
#   'track_href': 'https://api.spotify.com/v1/tracks/1mN0VG09xkwIDUE4d7YtpG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1mN0VG09xkwIDUE4d7YtpG',
#   'duration_ms': 212250,
#   'time_signature': 3},
#  '7A7pOBwLnrghUtt8ZrRZ2g': {'danceability': 0.655,
#   'energy': 0.47,
#   'key': 9,
#   'loudness': -4.292,
#   'mode': 1,
#   'speechiness': 0.031,
#   'acousticness': 0.0111,
#   'instrumentalness': 2.52e-05,
#   'liveness': 0.128,
#   'valence': 0.511,
#   'tempo': 135.897,
#   'type': 'audio_features',
#   'id': '7A7pOBwLnrghUtt8ZrRZ2g',
#   'uri': 'spotify:track:7A7pOBwLnrghUtt8ZrRZ2g',
#   'track_href': 'https://api.spotify.com/v1/tracks/7A7pOBwLnrghUtt8ZrRZ2g',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7A7pOBwLnrghUtt8ZrRZ2g',
#   'duration_ms': 183835,
#   'time_signature': 4},
#  '0s5Do4KNuYlcF0L9ZzDk6n': {'danceability': 0.548,
#   'energy': 0.308,
#   'key': 5,
#   'loudness': -16.438,
#   'mode': 1,
#   'speechiness': 0.218,
#   'acousticness': 0.83,
#   'instrumentalness': 0,
#   'liveness': 0.268,
#   'valence': 0.963,
#   'tempo': 148.26,
#   'type': 'audio_features',
#   'id': '0s5Do4KNuYlcF0L9ZzDk6n',
#   'uri': 'spotify:track:0s5Do4KNuYlcF0L9ZzDk6n',
#   'track_href': 'https://api.spotify.com/v1/tracks/0s5Do4KNuYlcF0L9ZzDk6n',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0s5Do4KNuYlcF0L9ZzDk6n',
#   'duration_ms': 194493,
#   'time_signature': 3},
#  '7bpdfUggKnTqaHrab7wl1G': {'danceability': 0.502,
#   'energy': 0.589,
#   'key': 0,
#   'loudness': -4.799,
#   'mode': 1,
#   'speechiness': 0.184,
#   'acousticness': 0.805,
#   'instrumentalness': 0,
#   'liveness': 0.285,
#   'valence': 0.962,
#   'tempo': 181.428,
#   'type': 'audio_features',
#   'id': '7bpdfUggKnTqaHrab7wl1G',
#   'uri': 'spotify:track:7bpdfUggKnTqaHrab7wl1G',
#   'track_href': 'https://api.spotify.com/v1/tracks/7bpdfUggKnTqaHrab7wl1G',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7bpdfUggKnTqaHrab7wl1G',
#   'duration_ms': 138577,
#   'time_signature': 3},
#  '2Tb9OIosEStb1zkItETEgf': {'danceability': 0.838,
#   'energy': 0.664,
#   'key': 11,
#   'loudness': -3.946,
#   'mode': 0,
#   'speechiness': 0.0317,
#   'acousticness': 0.327,
#   'instrumentalness': 0,
#   'liveness': 0.292,
#   'valence': 0.847,
#   'tempo': 124.874,
#   'type': 'audio_features',
#   'id': '2Tb9OIosEStb1zkItETEgf',
#   'uri': 'spotify:track:2Tb9OIosEStb1zkItETEgf',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Tb9OIosEStb1zkItETEgf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Tb9OIosEStb1zkItETEgf',
#   'duration_ms': 169473,
#   'time_signature': 4},
#  '5RfVZw4U54B1kI9ug4DulV': {'danceability': 0.869,
#   'energy': 0.791,
#   'key': 9,
#   'loudness': -6.046,
#   'mode': 1,
#   'speechiness': 0.0477,
#   'acousticness': 0.426,
#   'instrumentalness': 2.13e-05,
#   'liveness': 0.0964,
#   'valence': 0.929,
#   'tempo': 117.223,
#   'type': 'audio_features',
#   'id': '5RfVZw4U54B1kI9ug4DulV',
#   'uri': 'spotify:track:5RfVZw4U54B1kI9ug4DulV',
#   'track_href': 'https://api.spotify.com/v1/tracks/5RfVZw4U54B1kI9ug4DulV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5RfVZw4U54B1kI9ug4DulV',
#   'duration_ms': 246440,
#   'time_signature': 4},
#  '5yL9T1WK7fY0SFjnvSfima': {'danceability': 0.449,
#   'energy': 0.44,
#   'key': 9,
#   'loudness': -7.404,
#   'mode': 0,
#   'speechiness': 0.0264,
#   'acousticness': 0.347,
#   'instrumentalness': 3.68e-05,
#   'liveness': 0.227,
#   'valence': 0.291,
#   'tempo': 100.073,
#   'type': 'audio_features',
#   'id': '5yL9T1WK7fY0SFjnvSfima',
#   'uri': 'spotify:track:5yL9T1WK7fY0SFjnvSfima',
#   'track_href': 'https://api.spotify.com/v1/tracks/5yL9T1WK7fY0SFjnvSfima',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5yL9T1WK7fY0SFjnvSfima',
#   'duration_ms': 324365,
#   'time_signature': 3},
#  '3RVL3qjhY7lyXRlnhgYPLx': {'danceability': 0.797,
#   'energy': 0.538,
#   'key': 0,
#   'loudness': -12.131,
#   'mode': 1,
#   'speechiness': 0.043,
#   'acousticness': 0.315,
#   'instrumentalness': 0,
#   'liveness': 0.465,
#   'valence': 0.806,
#   'tempo': 107.093,
#   'type': 'audio_features',
#   'id': '3RVL3qjhY7lyXRlnhgYPLx',
#   'uri': 'spotify:track:3RVL3qjhY7lyXRlnhgYPLx',
#   'track_href': 'https://api.spotify.com/v1/tracks/3RVL3qjhY7lyXRlnhgYPLx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3RVL3qjhY7lyXRlnhgYPLx',
#   'duration_ms': 199427,
#   'time_signature': 4},
#  '4sljqDLRerjs19vDnylOT2': {'danceability': 0.768,
#   'energy': 0.939,
#   'key': 7,
#   'loudness': -1.912,
#   'mode': 1,
#   'speechiness': 0.15,
#   'acousticness': 0.231,
#   'instrumentalness': 0,
#   'liveness': 0.0906,
#   'valence': 0.962,
#   'tempo': 152.567,
#   'type': 'audio_features',
#   'id': '4sljqDLRerjs19vDnylOT2',
#   'uri': 'spotify:track:4sljqDLRerjs19vDnylOT2',
#   'track_href': 'https://api.spotify.com/v1/tracks/4sljqDLRerjs19vDnylOT2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4sljqDLRerjs19vDnylOT2',
#   'duration_ms': 170840,
#   'time_signature': 4},
#  '62F9ACDoMfuL9cxfr4BmEB': {'danceability': 0.754,
#   'energy': 0.495,
#   'key': 9,
#   'loudness': -6.678,
#   'mode': 1,
#   'speechiness': 0.0462,
#   'acousticness': 0.495,
#   'instrumentalness': 0,
#   'liveness': 0.0278,
#   'valence': 0.949,
#   'tempo': 114.888,
#   'type': 'audio_features',
#   'id': '62F9ACDoMfuL9cxfr4BmEB',
#   'uri': 'spotify:track:62F9ACDoMfuL9cxfr4BmEB',
#   'track_href': 'https://api.spotify.com/v1/tracks/62F9ACDoMfuL9cxfr4BmEB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/62F9ACDoMfuL9cxfr4BmEB',
#   'duration_ms': 129707,
#   'time_signature': 4},
#  '5pckd4xNB6DxRCeJNeqPOz': {'danceability': 0.783,
#   'energy': 0.631,
#   'key': 1,
#   'loudness': -4.078,
#   'mode': 0,
#   'speechiness': 0.0381,
#   'acousticness': 0.13,
#   'instrumentalness': 0,
#   'liveness': 0.0928,
#   'valence': 0.906,
#   'tempo': 123.866,
#   'type': 'audio_features',
#   'id': '5pckd4xNB6DxRCeJNeqPOz',
#   'uri': 'spotify:track:5pckd4xNB6DxRCeJNeqPOz',
#   'track_href': 'https://api.spotify.com/v1/tracks/5pckd4xNB6DxRCeJNeqPOz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5pckd4xNB6DxRCeJNeqPOz',
#   'duration_ms': 166347,
#   'time_signature': 4},
#  '4qjH5eIWdoBl4v3oLQwKB8': {'danceability': 0.884,
#   'energy': 0.243,
#   'key': 9,
#   'loudness': -13.745,
#   'mode': 1,
#   'speechiness': 0.0528,
#   'acousticness': 0.738,
#   'instrumentalness': 0,
#   'liveness': 0.0373,
#   'valence': 0.964,
#   'tempo': 107.636,
#   'type': 'audio_features',
#   'id': '4qjH5eIWdoBl4v3oLQwKB8',
#   'uri': 'spotify:track:4qjH5eIWdoBl4v3oLQwKB8',
#   'track_href': 'https://api.spotify.com/v1/tracks/4qjH5eIWdoBl4v3oLQwKB8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4qjH5eIWdoBl4v3oLQwKB8',
#   'duration_ms': 186093,
#   'time_signature': 4},
#  '1wahJcvVpT4rQv27VOXK0u': {'danceability': 0.526,
#   'energy': 0.452,
#   'key': 9,
#   'loudness': -5.444,
#   'mode': 0,
#   'speechiness': 0.027,
#   'acousticness': 0.142,
#   'instrumentalness': 0,
#   'liveness': 0.0458,
#   'valence': 0.474,
#   'tempo': 131.952,
#   'type': 'audio_features',
#   'id': '1wahJcvVpT4rQv27VOXK0u',
#   'uri': 'spotify:track:1wahJcvVpT4rQv27VOXK0u',
#   'track_href': 'https://api.spotify.com/v1/tracks/1wahJcvVpT4rQv27VOXK0u',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1wahJcvVpT4rQv27VOXK0u',
#   'duration_ms': 205021,
#   'time_signature': 4},
#  '7mf5vUur0sowp4GNDCtvCj': {'danceability': 0.743,
#   'energy': 0.474,
#   'key': 4,
#   'loudness': -10.279,
#   'mode': 1,
#   'speechiness': 0.0785,
#   'acousticness': 0.461,
#   'instrumentalness': 0,
#   'liveness': 0.0649,
#   'valence': 0.829,
#   'tempo': 114.165,
#   'type': 'audio_features',
#   'id': '7mf5vUur0sowp4GNDCtvCj',
#   'uri': 'spotify:track:7mf5vUur0sowp4GNDCtvCj',
#   'track_href': 'https://api.spotify.com/v1/tracks/7mf5vUur0sowp4GNDCtvCj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7mf5vUur0sowp4GNDCtvCj',
#   'duration_ms': 231640,
#   'time_signature': 4},
#  '4NB4NBmRjEp831NOfVfgpP': {'danceability': 0.748,
#   'energy': 0.697,
#   'key': 1,
#   'loudness': -6.022,
#   'mode': 0,
#   'speechiness': 0.107,
#   'acousticness': 0.456,
#   'instrumentalness': 0,
#   'liveness': 0.404,
#   'valence': 0.831,
#   'tempo': 94.003,
#   'type': 'audio_features',
#   'id': '4NB4NBmRjEp831NOfVfgpP',
#   'uri': 'spotify:track:4NB4NBmRjEp831NOfVfgpP',
#   'track_href': 'https://api.spotify.com/v1/tracks/4NB4NBmRjEp831NOfVfgpP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4NB4NBmRjEp831NOfVfgpP',
#   'duration_ms': 183520,
#   'time_signature': 4},
#  '1QxczGOV8KSDssFCLfynqn': {'danceability': 0.536,
#   'energy': 0.53,
#   'key': 4,
#   'loudness': -4.932,
#   'mode': 1,
#   'speechiness': 0.047,
#   'acousticness': 0.697,
#   'instrumentalness': 1.15e-05,
#   'liveness': 0.114,
#   'valence': 0.774,
#   'tempo': 199.878,
#   'type': 'audio_features',
#   'id': '1QxczGOV8KSDssFCLfynqn',
#   'uri': 'spotify:track:1QxczGOV8KSDssFCLfynqn',
#   'track_href': 'https://api.spotify.com/v1/tracks/1QxczGOV8KSDssFCLfynqn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1QxczGOV8KSDssFCLfynqn',
#   'duration_ms': 240588,
#   'time_signature': 3},
#  '5FNYjiqxvpX29jR6rtjQrj': {'danceability': 0.573,
#   'energy': 0.594,
#   'key': 2,
#   'loudness': -8.246,
#   'mode': 1,
#   'speechiness': 0.0484,
#   'acousticness': 0.415,
#   'instrumentalness': 0,
#   'liveness': 0.142,
#   'valence': 0.667,
#   'tempo': 145.531,
#   'type': 'audio_features',
#   'id': '5FNYjiqxvpX29jR6rtjQrj',
#   'uri': 'spotify:track:5FNYjiqxvpX29jR6rtjQrj',
#   'track_href': 'https://api.spotify.com/v1/tracks/5FNYjiqxvpX29jR6rtjQrj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5FNYjiqxvpX29jR6rtjQrj',
#   'duration_ms': 208200,
#   'time_signature': 4},
#  '7uRNVP2qYcA6dusH4y0wTv': {'danceability': 0.769,
#   'energy': 0.492,
#   'key': 9,
#   'loudness': -4.318,
#   'mode': 1,
#   'speechiness': 0.0321,
#   'acousticness': 0.0842,
#   'instrumentalness': 4.86e-05,
#   'liveness': 0.0617,
#   'valence': 0.581,
#   'tempo': 110.048,
#   'type': 'audio_features',
#   'id': '7uRNVP2qYcA6dusH4y0wTv',
#   'uri': 'spotify:track:7uRNVP2qYcA6dusH4y0wTv',
#   'track_href': 'https://api.spotify.com/v1/tracks/7uRNVP2qYcA6dusH4y0wTv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7uRNVP2qYcA6dusH4y0wTv',
#   'duration_ms': 148864,
#   'time_signature': 4},
#  '6zbLGCjIPY4U4jQzpcq32H': {'danceability': 0.507,
#   'energy': 0.652,
#   'key': 0,
#   'loudness': -6.822,
#   'mode': 0,
#   'speechiness': 0.0899,
#   'acousticness': 0.585,
#   'instrumentalness': 0,
#   'liveness': 0.265,
#   'valence': 0.71,
#   'tempo': 152.498,
#   'type': 'audio_features',
#   'id': '6zbLGCjIPY4U4jQzpcq32H',
#   'uri': 'spotify:track:6zbLGCjIPY4U4jQzpcq32H',
#   'track_href': 'https://api.spotify.com/v1/tracks/6zbLGCjIPY4U4jQzpcq32H',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6zbLGCjIPY4U4jQzpcq32H',
#   'duration_ms': 286851,
#   'time_signature': 4},
#  ...}

# %% [markdown]
# Here i turned the dictionary to a DataFrame.

# %%
tracks_analysis = pd.DataFrame.from_dict(features, orient='index')
tracks_analysis
# Out:
#                         danceability  energy  key  loudness  mode  \
# 4fouWK6XVHhzl78KzQ1UjL         0.695   0.540    4    -5.692     1
# 3Vi5XqYrmQgOYBajMWSvCi         0.664   0.609    1    -6.509     1
# 4ZtFanR9U6ndgddUvNcjcG         0.563   0.664    9    -5.044     1
# 6Uj1ctrBOjOas8xZXGqKk4         0.824   0.764    5    -4.175     0
# 27NovPIUIRrOZoCHxABJwK         0.736   0.704    3    -7.409     0
# ...                              ...     ...  ...       ...   ...
# 3Evwk0LpaDBxZw5XivAnAW         0.739   0.874    7    -3.317     0
# 6lVnWrqFYadbLQQXJ3eSbq         0.692   0.767   11    -5.791     0
# 6o70OF4tqIT43azQ8gR7Y6         0.590   0.735    8    -4.621     1
# 62QYD9QijBwm26Id8azkcR         0.547   0.685    9   -10.666     0
# 7APrqpJyEIkUMEtKerIz88         0.610   0.626    5    -8.773     1
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# 4fouWK6XVHhzl78KzQ1UjL       0.0493        0.2990           0.00000    0.3670
# 3Vi5XqYrmQgOYBajMWSvCi       0.0707        0.3040           0.00000    0.0926
# 4ZtFanR9U6ndgddUvNcjcG       0.1540        0.3350           0.00000    0.0849
# 6Uj1ctrBOjOas8xZXGqKk4       0.0854        0.0888           0.00294    0.1170
# 27NovPIUIRrOZoCHxABJwK       0.0615        0.0203           0.00000    0.0501
# ...                             ...           ...               ...       ...
# 3Evwk0LpaDBxZw5XivAnAW       0.2360        0.3140           0.00000    0.1050
# 6lVnWrqFYadbLQQXJ3eSbq       0.0401        0.3500           0.00000    0.0905
# 6o70OF4tqIT43azQ8gR7Y6       0.3000        0.0901           0.76500    0.1120
# 62QYD9QijBwm26Id8azkcR       0.0312        0.1610           0.93300    0.9140
# 7APrqpJyEIkUMEtKerIz88       0.0318        0.2890           0.00000    0.3150
#
#                         valence    tempo            type  \
# 4fouWK6XVHhzl78KzQ1UjL   0.4150  121.932  audio_features
# 3Vi5XqYrmQgOYBajMWSvCi   0.1940  130.041  audio_features
# 4ZtFanR9U6ndgddUvNcjcG   0.6880  166.928  audio_features
# 6Uj1ctrBOjOas8xZXGqKk4   0.8810  107.998  audio_features
# 27NovPIUIRrOZoCHxABJwK   0.8940  149.995  audio_features
# ...                         ...      ...             ...
# 3Evwk0LpaDBxZw5XivAnAW   0.7670   95.055  audio_features
# 6lVnWrqFYadbLQQXJ3eSbq   0.7600  139.930  audio_features
# 6o70OF4tqIT43azQ8gR7Y6   0.0584  137.925  audio_features
# 62QYD9QijBwm26Id8azkcR   0.3660  130.063  audio_features
# 7APrqpJyEIkUMEtKerIz88   0.8370  130.452  audio_features
#
#                                             id  \
# 4fouWK6XVHhzl78KzQ1UjL  4fouWK6XVHhzl78KzQ1UjL
# 3Vi5XqYrmQgOYBajMWSvCi  3Vi5XqYrmQgOYBajMWSvCi
# 4ZtFanR9U6ndgddUvNcjcG  4ZtFanR9U6ndgddUvNcjcG
# 6Uj1ctrBOjOas8xZXGqKk4  6Uj1ctrBOjOas8xZXGqKk4
# 27NovPIUIRrOZoCHxABJwK  27NovPIUIRrOZoCHxABJwK
# ...                                        ...
# 3Evwk0LpaDBxZw5XivAnAW  3Evwk0LpaDBxZw5XivAnAW
# 6lVnWrqFYadbLQQXJ3eSbq  6lVnWrqFYadbLQQXJ3eSbq
# 6o70OF4tqIT43azQ8gR7Y6  6o70OF4tqIT43azQ8gR7Y6
# 62QYD9QijBwm26Id8azkcR  62QYD9QijBwm26Id8azkcR
# 7APrqpJyEIkUMEtKerIz88  7APrqpJyEIkUMEtKerIz88
#
#                                                          uri  \
# 4fouWK6XVHhzl78KzQ1UjL  spotify:track:4fouWK6XVHhzl78KzQ1UjL
# 3Vi5XqYrmQgOYBajMWSvCi  spotify:track:3Vi5XqYrmQgOYBajMWSvCi
# 4ZtFanR9U6ndgddUvNcjcG  spotify:track:4ZtFanR9U6ndgddUvNcjcG
# 6Uj1ctrBOjOas8xZXGqKk4  spotify:track:6Uj1ctrBOjOas8xZXGqKk4
# 27NovPIUIRrOZoCHxABJwK  spotify:track:27NovPIUIRrOZoCHxABJwK
# ...                                                      ...
# 3Evwk0LpaDBxZw5XivAnAW  spotify:track:3Evwk0LpaDBxZw5XivAnAW
# 6lVnWrqFYadbLQQXJ3eSbq  spotify:track:6lVnWrqFYadbLQQXJ3eSbq
# 6o70OF4tqIT43azQ8gR7Y6  spotify:track:6o70OF4tqIT43azQ8gR7Y6
# 62QYD9QijBwm26Id8azkcR  spotify:track:62QYD9QijBwm26Id8azkcR
# 7APrqpJyEIkUMEtKerIz88  spotify:track:7APrqpJyEIkUMEtKerIz88
#
#                                                                track_href  \
# 4fouWK6XVHhzl78KzQ1UjL  https://api.spotify.com/v1/tracks/4fouWK6XVHhz...
# 3Vi5XqYrmQgOYBajMWSvCi  https://api.spotify.com/v1/tracks/3Vi5XqYrmQgO...
# 4ZtFanR9U6ndgddUvNcjcG  https://api.spotify.com/v1/tracks/4ZtFanR9U6nd...
# 6Uj1ctrBOjOas8xZXGqKk4  https://api.spotify.com/v1/tracks/6Uj1ctrBOjOa...
# 27NovPIUIRrOZoCHxABJwK  https://api.spotify.com/v1/tracks/27NovPIUIRrO...
# ...                                                                   ...
# 3Evwk0LpaDBxZw5XivAnAW  https://api.spotify.com/v1/tracks/3Evwk0LpaDBx...
# 6lVnWrqFYadbLQQXJ3eSbq  https://api.spotify.com/v1/tracks/6lVnWrqFYadb...
# 6o70OF4tqIT43azQ8gR7Y6  https://api.spotify.com/v1/tracks/6o70OF4tqIT4...
# 62QYD9QijBwm26Id8azkcR  https://api.spotify.com/v1/tracks/62QYD9QijBwm...
# 7APrqpJyEIkUMEtKerIz88  https://api.spotify.com/v1/tracks/7APrqpJyEIkU...
#
#                                                              analysis_url  \
# 4fouWK6XVHhzl78KzQ1UjL  https://api.spotify.com/v1/audio-analysis/4fou...
# 3Vi5XqYrmQgOYBajMWSvCi  https://api.spotify.com/v1/audio-analysis/3Vi5...
# 4ZtFanR9U6ndgddUvNcjcG  https://api.spotify.com/v1/audio-analysis/4ZtF...
# 6Uj1ctrBOjOas8xZXGqKk4  https://api.spotify.com/v1/audio-analysis/6Uj1...
# 27NovPIUIRrOZoCHxABJwK  https://api.spotify.com/v1/audio-analysis/27No...
# ...                                                                   ...
# 3Evwk0LpaDBxZw5XivAnAW  https://api.spotify.com/v1/audio-analysis/3Evw...
# 6lVnWrqFYadbLQQXJ3eSbq  https://api.spotify.com/v1/audio-analysis/6lVn...
# 6o70OF4tqIT43azQ8gR7Y6  https://api.spotify.com/v1/audio-analysis/6o70...
# 62QYD9QijBwm26Id8azkcR  https://api.spotify.com/v1/audio-analysis/62QY...
# 7APrqpJyEIkUMEtKerIz88  https://api.spotify.com/v1/audio-analysis/7APr...
#
#                         duration_ms  time_signature
# 4fouWK6XVHhzl78KzQ1UjL       168602               4
# 3Vi5XqYrmQgOYBajMWSvCi       210560               4
# 4ZtFanR9U6ndgddUvNcjcG       178147               4
# 6Uj1ctrBOjOas8xZXGqKk4       172627               4
# 27NovPIUIRrOZoCHxABJwK       212000               4
# ...                             ...             ...
# 3Evwk0LpaDBxZw5XivAnAW       188211               4
# 6lVnWrqFYadbLQQXJ3eSbq       213333               4
# 6o70OF4tqIT43azQ8gR7Y6       340870               4
# 62QYD9QijBwm26Id8azkcR       187227               4
# 7APrqpJyEIkUMEtKerIz88       240733               4
#
# [17608 rows x 18 columns]

# %% [markdown]
# I moved the index as a column called `song_id`.

# %%
tracks_analysis = tracks_analysis.reset_index().rename(columns={'index' : 'song_id'})
tracks_analysis
# Out:
#                       song_id  danceability  energy  key  loudness  mode  \
# 0      4fouWK6XVHhzl78KzQ1UjL         0.695   0.540    4    -5.692     1
# 1      3Vi5XqYrmQgOYBajMWSvCi         0.664   0.609    1    -6.509     1
# 2      4ZtFanR9U6ndgddUvNcjcG         0.563   0.664    9    -5.044     1
# 3      6Uj1ctrBOjOas8xZXGqKk4         0.824   0.764    5    -4.175     0
# 4      27NovPIUIRrOZoCHxABJwK         0.736   0.704    3    -7.409     0
# ...                       ...           ...     ...  ...       ...   ...
# 17603  3Evwk0LpaDBxZw5XivAnAW         0.739   0.874    7    -3.317     0
# 17604  6lVnWrqFYadbLQQXJ3eSbq         0.692   0.767   11    -5.791     0
# 17605  6o70OF4tqIT43azQ8gR7Y6         0.590   0.735    8    -4.621     1
# 17606  62QYD9QijBwm26Id8azkcR         0.547   0.685    9   -10.666     0
# 17607  7APrqpJyEIkUMEtKerIz88         0.610   0.626    5    -8.773     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 0           0.0493        0.2990           0.00000    0.3670   0.4150
# 1           0.0707        0.3040           0.00000    0.0926   0.1940
# 2           0.1540        0.3350           0.00000    0.0849   0.6880
# 3           0.0854        0.0888           0.00294    0.1170   0.8810
# 4           0.0615        0.0203           0.00000    0.0501   0.8940
# ...            ...           ...               ...       ...      ...
# 17603       0.2360        0.3140           0.00000    0.1050   0.7670
# 17604       0.0401        0.3500           0.00000    0.0905   0.7600
# 17605       0.3000        0.0901           0.76500    0.1120   0.0584
# 17606       0.0312        0.1610           0.93300    0.9140   0.3660
# 17607       0.0318        0.2890           0.00000    0.3150   0.8370
#
#          tempo            type                      id  \
# 0      121.932  audio_features  4fouWK6XVHhzl78KzQ1UjL
# 1      130.041  audio_features  3Vi5XqYrmQgOYBajMWSvCi
# 2      166.928  audio_features  4ZtFanR9U6ndgddUvNcjcG
# 3      107.998  audio_features  6Uj1ctrBOjOas8xZXGqKk4
# 4      149.995  audio_features  27NovPIUIRrOZoCHxABJwK
# ...        ...             ...                     ...
# 17603   95.055  audio_features  3Evwk0LpaDBxZw5XivAnAW
# 17604  139.930  audio_features  6lVnWrqFYadbLQQXJ3eSbq
# 17605  137.925  audio_features  6o70OF4tqIT43azQ8gR7Y6
# 17606  130.063  audio_features  62QYD9QijBwm26Id8azkcR
# 17607  130.452  audio_features  7APrqpJyEIkUMEtKerIz88
#
#                                         uri  \
# 0      spotify:track:4fouWK6XVHhzl78KzQ1UjL
# 1      spotify:track:3Vi5XqYrmQgOYBajMWSvCi
# 2      spotify:track:4ZtFanR9U6ndgddUvNcjcG
# 3      spotify:track:6Uj1ctrBOjOas8xZXGqKk4
# 4      spotify:track:27NovPIUIRrOZoCHxABJwK
# ...                                     ...
# 17603  spotify:track:3Evwk0LpaDBxZw5XivAnAW
# 17604  spotify:track:6lVnWrqFYadbLQQXJ3eSbq
# 17605  spotify:track:6o70OF4tqIT43azQ8gR7Y6
# 17606  spotify:track:62QYD9QijBwm26Id8azkcR
# 17607  spotify:track:7APrqpJyEIkUMEtKerIz88
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/4fouWK6XVHhz...
# 1      https://api.spotify.com/v1/tracks/3Vi5XqYrmQgO...
# 2      https://api.spotify.com/v1/tracks/4ZtFanR9U6nd...
# 3      https://api.spotify.com/v1/tracks/6Uj1ctrBOjOa...
# 4      https://api.spotify.com/v1/tracks/27NovPIUIRrO...
# ...                                                  ...
# 17603  https://api.spotify.com/v1/tracks/3Evwk0LpaDBx...
# 17604  https://api.spotify.com/v1/tracks/6lVnWrqFYadb...
# 17605  https://api.spotify.com/v1/tracks/6o70OF4tqIT4...
# 17606  https://api.spotify.com/v1/tracks/62QYD9QijBwm...
# 17607  https://api.spotify.com/v1/tracks/7APrqpJyEIkU...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/4fou...       168602
# 1      https://api.spotify.com/v1/audio-analysis/3Vi5...       210560
# 2      https://api.spotify.com/v1/audio-analysis/4ZtF...       178147
# 3      https://api.spotify.com/v1/audio-analysis/6Uj1...       172627
# 4      https://api.spotify.com/v1/audio-analysis/27No...       212000
# ...                                                  ...          ...
# 17603  https://api.spotify.com/v1/audio-analysis/3Evw...       188211
# 17604  https://api.spotify.com/v1/audio-analysis/6lVn...       213333
# 17605  https://api.spotify.com/v1/audio-analysis/6o70...       340870
# 17606  https://api.spotify.com/v1/audio-analysis/62QY...       187227
# 17607  https://api.spotify.com/v1/audio-analysis/7APr...       240733
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 17603               4
# 17604               4
# 17605               4
# 17606               4
# 17607               4
#
# [17608 rows x 19 columns]

# %% [markdown]
# Finally, i saved the dataset to `tracks_features.csv`. The dataset i used for dissecting Spotify's Valence metric is stored in `data/tracks_features.csv`.

# %%
tracks_analysis.to_csv('tracks_features.csv', index=False)

# %% [markdown]
# ## Testing Dataset
#
# For testing dataset, i took all the ids from spotify_ids.txt.

# %%
testdf = pd.read_csv('data\spotify_ids.txt', header=None, sep=' ')
testdf
# Out:
#                            0
# 0     7lPN2DXiMsVn7XUKtOW1CS
# 1     5QO79kh1waicV47BqGRL3g
# 2     0VjIjW4GlUZAMYd2vXMi3b
# 3     4MzXwWMhyBbmu6hOcLVD49
# 4     5Kskr9LcNYa0tpt5f0ZEJx
# ...                      ...
# 1157  4lUmnwRybYH7mMzf16xB0y
# 1158  1fzf9Aad4y1RWrmwosAK5y
# 1159  3E3pb3qH11iny6TFDJvsg5
# 1160  3yTkoTuiKRGL2VAlQd7xsC
# 1161  4JE6agBLHGA5TaF6FlqfBD
#
# [1162 rows x 1 columns]

# %% [markdown]
# Then i renamed `0` colum to `id`.

# %%
testdf = testdf.rename(columns={0 : 'id'})
testdf
# Out:
#                           id
# 0     7lPN2DXiMsVn7XUKtOW1CS
# 1     5QO79kh1waicV47BqGRL3g
# 2     0VjIjW4GlUZAMYd2vXMi3b
# 3     4MzXwWMhyBbmu6hOcLVD49
# 4     5Kskr9LcNYa0tpt5f0ZEJx
# ...                      ...
# 1157  4lUmnwRybYH7mMzf16xB0y
# 1158  1fzf9Aad4y1RWrmwosAK5y
# 1159  3E3pb3qH11iny6TFDJvsg5
# 1160  3yTkoTuiKRGL2VAlQd7xsC
# 1161  4JE6agBLHGA5TaF6FlqfBD
#
# [1162 rows x 1 columns]

# %% [markdown]
# Then i got, for each of the tracks, its audio features.
#
# In order to do that, i created a dictionary keyed by id, with values being the audio features for the specific track.

# %%
test_features = {}
all_test_track_ids = list(testdf['id'].unique())
start = 0
num_tracks = 100
  
while start < len(all_test_track_ids):
    print(f'getting from {start} to {start+num_tracks}')
    tracks_batch = all_test_track_ids[start:start+num_tracks]
    features_batch = sp.audio_features(tracks_batch)
    test_features.update({ track_id : track_features 
                     for track_id, track_features in zip(tracks_batch, features_batch) })
    start += num_tracks
# Out:
# getting from 0 to 100
# getting from 100 to 200
# getting from 200 to 300
# getting from 300 to 400
# getting from 400 to 500
# getting from 500 to 600
# getting from 600 to 700
# getting from 700 to 800
# getting from 800 to 900
# getting from 900 to 1000
# getting from 1000 to 1100
# getting from 1100 to 1200

# %% [markdown]
# Here i turned the dictionary to a DataFrame.

# %%
test_tracks_analysis = pd.DataFrame.from_dict(test_features, orient='index')
test_tracks_analysis
# Out:
#                         danceability  energy  key  loudness  mode  \
# 7lPN2DXiMsVn7XUKtOW1CS         0.585   0.436   10    -8.761     1
# 5QO79kh1waicV47BqGRL3g         0.680   0.826    0    -5.487     1
# 0VjIjW4GlUZAMYd2vXMi3b         0.514   0.730    1    -5.934     1
# 4MzXwWMhyBbmu6hOcLVD49         0.731   0.573    4   -10.059     0
# 5Kskr9LcNYa0tpt5f0ZEJx         0.907   0.393    4    -7.636     0
# ...                              ...     ...  ...       ...   ...
# 4lUmnwRybYH7mMzf16xB0y         0.596   0.650    9    -5.167     1
# 1fzf9Aad4y1RWrmwosAK5y         0.588   0.850    4    -6.431     1
# 3E3pb3qH11iny6TFDJvsg5         0.754   0.660    0    -6.811     1
# 3yTkoTuiKRGL2VAlQd7xsC         0.584   0.836    0    -4.925     1
# 4JE6agBLHGA5TaF6FlqfBD         0.331   0.450   10    -5.362     1
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# 7lPN2DXiMsVn7XUKtOW1CS       0.0601       0.72100          0.000013    0.1050
# 5QO79kh1waicV47BqGRL3g       0.0309       0.02120          0.000012    0.5430
# 0VjIjW4GlUZAMYd2vXMi3b       0.0598       0.00146          0.000095    0.0897
# 4MzXwWMhyBbmu6hOcLVD49       0.0544       0.40100          0.000052    0.1130
# 5Kskr9LcNYa0tpt5f0ZEJx       0.0539       0.45100          0.000001    0.1350
# ...                             ...           ...               ...       ...
# 4lUmnwRybYH7mMzf16xB0y       0.3370       0.13800          0.000000    0.1400
# 1fzf9Aad4y1RWrmwosAK5y       0.0318       0.16800          0.002020    0.0465
# 3E3pb3qH11iny6TFDJvsg5       0.2670       0.17900          0.000000    0.1940
# 3yTkoTuiKRGL2VAlQd7xsC       0.0790       0.05580          0.000000    0.0663
# 4JE6agBLHGA5TaF6FlqfBD       0.0340       0.36500          0.004640    0.2200
#
#                         valence    tempo            type  \
# 7lPN2DXiMsVn7XUKtOW1CS    0.132  143.874  audio_features
# 5QO79kh1waicV47BqGRL3g    0.644  118.051  audio_features
# 0VjIjW4GlUZAMYd2vXMi3b    0.334  171.005  audio_features
# 4MzXwWMhyBbmu6hOcLVD49    0.145  109.928  audio_features
# 5Kskr9LcNYa0tpt5f0ZEJx    0.202  104.949  audio_features
# ...                         ...      ...             ...
# 4lUmnwRybYH7mMzf16xB0y    0.188  133.997  audio_features
# 1fzf9Aad4y1RWrmwosAK5y    0.768   93.003  audio_features
# 3E3pb3qH11iny6TFDJvsg5    0.316   83.000  audio_features
# 3yTkoTuiKRGL2VAlQd7xsC    0.484  104.973  audio_features
# 4JE6agBLHGA5TaF6FlqfBD    0.180  123.829  audio_features
#
#                                             id  \
# 7lPN2DXiMsVn7XUKtOW1CS  7lPN2DXiMsVn7XUKtOW1CS
# 5QO79kh1waicV47BqGRL3g  5QO79kh1waicV47BqGRL3g
# 0VjIjW4GlUZAMYd2vXMi3b  0VjIjW4GlUZAMYd2vXMi3b
# 4MzXwWMhyBbmu6hOcLVD49  4MzXwWMhyBbmu6hOcLVD49
# 5Kskr9LcNYa0tpt5f0ZEJx  5Kskr9LcNYa0tpt5f0ZEJx
# ...                                        ...
# 4lUmnwRybYH7mMzf16xB0y  4lUmnwRybYH7mMzf16xB0y
# 1fzf9Aad4y1RWrmwosAK5y  1fzf9Aad4y1RWrmwosAK5y
# 3E3pb3qH11iny6TFDJvsg5  3E3pb3qH11iny6TFDJvsg5
# 3yTkoTuiKRGL2VAlQd7xsC  3yTkoTuiKRGL2VAlQd7xsC
# 4JE6agBLHGA5TaF6FlqfBD  4JE6agBLHGA5TaF6FlqfBD
#
#                                                          uri  \
# 7lPN2DXiMsVn7XUKtOW1CS  spotify:track:7lPN2DXiMsVn7XUKtOW1CS
# 5QO79kh1waicV47BqGRL3g  spotify:track:5QO79kh1waicV47BqGRL3g
# 0VjIjW4GlUZAMYd2vXMi3b  spotify:track:0VjIjW4GlUZAMYd2vXMi3b
# 4MzXwWMhyBbmu6hOcLVD49  spotify:track:4MzXwWMhyBbmu6hOcLVD49
# 5Kskr9LcNYa0tpt5f0ZEJx  spotify:track:5Kskr9LcNYa0tpt5f0ZEJx
# ...                                                      ...
# 4lUmnwRybYH7mMzf16xB0y  spotify:track:4lUmnwRybYH7mMzf16xB0y
# 1fzf9Aad4y1RWrmwosAK5y  spotify:track:1fzf9Aad4y1RWrmwosAK5y
# 3E3pb3qH11iny6TFDJvsg5  spotify:track:3E3pb3qH11iny6TFDJvsg5
# 3yTkoTuiKRGL2VAlQd7xsC  spotify:track:3yTkoTuiKRGL2VAlQd7xsC
# 4JE6agBLHGA5TaF6FlqfBD  spotify:track:4JE6agBLHGA5TaF6FlqfBD
#
#                                                                track_href  \
# 7lPN2DXiMsVn7XUKtOW1CS  https://api.spotify.com/v1/tracks/7lPN2DXiMsVn...
# 5QO79kh1waicV47BqGRL3g  https://api.spotify.com/v1/tracks/5QO79kh1waic...
# 0VjIjW4GlUZAMYd2vXMi3b  https://api.spotify.com/v1/tracks/0VjIjW4GlUZA...
# 4MzXwWMhyBbmu6hOcLVD49  https://api.spotify.com/v1/tracks/4MzXwWMhyBbm...
# 5Kskr9LcNYa0tpt5f0ZEJx  https://api.spotify.com/v1/tracks/5Kskr9LcNYa0...
# ...                                                                   ...
# 4lUmnwRybYH7mMzf16xB0y  https://api.spotify.com/v1/tracks/4lUmnwRybYH7...
# 1fzf9Aad4y1RWrmwosAK5y  https://api.spotify.com/v1/tracks/1fzf9Aad4y1R...
# 3E3pb3qH11iny6TFDJvsg5  https://api.spotify.com/v1/tracks/3E3pb3qH11in...
# 3yTkoTuiKRGL2VAlQd7xsC  https://api.spotify.com/v1/tracks/3yTkoTuiKRGL...
# 4JE6agBLHGA5TaF6FlqfBD  https://api.spotify.com/v1/tracks/4JE6agBLHGA5...
#
#                                                              analysis_url  \
# 7lPN2DXiMsVn7XUKtOW1CS  https://api.spotify.com/v1/audio-analysis/7lPN...
# 5QO79kh1waicV47BqGRL3g  https://api.spotify.com/v1/audio-analysis/5QO7...
# 0VjIjW4GlUZAMYd2vXMi3b  https://api.spotify.com/v1/audio-analysis/0VjI...
# 4MzXwWMhyBbmu6hOcLVD49  https://api.spotify.com/v1/audio-analysis/4MzX...
# 5Kskr9LcNYa0tpt5f0ZEJx  https://api.spotify.com/v1/audio-analysis/5Ksk...
# ...                                                                   ...
# 4lUmnwRybYH7mMzf16xB0y  https://api.spotify.com/v1/audio-analysis/4lUm...
# 1fzf9Aad4y1RWrmwosAK5y  https://api.spotify.com/v1/audio-analysis/1fzf...
# 3E3pb3qH11iny6TFDJvsg5  https://api.spotify.com/v1/audio-analysis/3E3p...
# 3yTkoTuiKRGL2VAlQd7xsC  https://api.spotify.com/v1/audio-analysis/3yTk...
# 4JE6agBLHGA5TaF6FlqfBD  https://api.spotify.com/v1/audio-analysis/4JE6...
#
#                         duration_ms  time_signature
# 7lPN2DXiMsVn7XUKtOW1CS       242014               4
# 5QO79kh1waicV47BqGRL3g       215627               4
# 0VjIjW4GlUZAMYd2vXMi3b       200040               4
# 4MzXwWMhyBbmu6hOcLVD49       205090               4
# 5Kskr9LcNYa0tpt5f0ZEJx       205458               4
# ...                             ...             ...
# 4lUmnwRybYH7mMzf16xB0y       257428               4
# 1fzf9Aad4y1RWrmwosAK5y       187310               4
# 3E3pb3qH11iny6TFDJvsg5       209299               4
# 3yTkoTuiKRGL2VAlQd7xsC       202204               4
# 4JE6agBLHGA5TaF6FlqfBD       218755               4
#
# [1162 rows x 18 columns]

# %% [markdown]
# I moved the index as a column called `song_id`.

# %%
test_tracks_analysis = test_tracks_analysis.reset_index().rename(columns={'index' : 'song_id'})
test_tracks_analysis
# Out:
#                      song_id  danceability  energy  key  loudness  mode  \
# 0     7lPN2DXiMsVn7XUKtOW1CS         0.585   0.436   10    -8.761     1
# 1     5QO79kh1waicV47BqGRL3g         0.680   0.826    0    -5.487     1
# 2     0VjIjW4GlUZAMYd2vXMi3b         0.514   0.730    1    -5.934     1
# 3     4MzXwWMhyBbmu6hOcLVD49         0.731   0.573    4   -10.059     0
# 4     5Kskr9LcNYa0tpt5f0ZEJx         0.907   0.393    4    -7.636     0
# ...                      ...           ...     ...  ...       ...   ...
# 1157  4lUmnwRybYH7mMzf16xB0y         0.596   0.650    9    -5.167     1
# 1158  1fzf9Aad4y1RWrmwosAK5y         0.588   0.850    4    -6.431     1
# 1159  3E3pb3qH11iny6TFDJvsg5         0.754   0.660    0    -6.811     1
# 1160  3yTkoTuiKRGL2VAlQd7xsC         0.584   0.836    0    -4.925     1
# 1161  4JE6agBLHGA5TaF6FlqfBD         0.331   0.450   10    -5.362     1
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.0601       0.72100          0.000013    0.1050    0.132  143.874
# 1          0.0309       0.02120          0.000012    0.5430    0.644  118.051
# 2          0.0598       0.00146          0.000095    0.0897    0.334  171.005
# 3          0.0544       0.40100          0.000052    0.1130    0.145  109.928
# 4          0.0539       0.45100          0.000001    0.1350    0.202  104.949
# ...           ...           ...               ...       ...      ...      ...
# 1157       0.3370       0.13800          0.000000    0.1400    0.188  133.997
# 1158       0.0318       0.16800          0.002020    0.0465    0.768   93.003
# 1159       0.2670       0.17900          0.000000    0.1940    0.316   83.000
# 1160       0.0790       0.05580          0.000000    0.0663    0.484  104.973
# 1161       0.0340       0.36500          0.004640    0.2200    0.180  123.829
#
#                 type                      id  \
# 0     audio_features  7lPN2DXiMsVn7XUKtOW1CS
# 1     audio_features  5QO79kh1waicV47BqGRL3g
# 2     audio_features  0VjIjW4GlUZAMYd2vXMi3b
# 3     audio_features  4MzXwWMhyBbmu6hOcLVD49
# 4     audio_features  5Kskr9LcNYa0tpt5f0ZEJx
# ...              ...                     ...
# 1157  audio_features  4lUmnwRybYH7mMzf16xB0y
# 1158  audio_features  1fzf9Aad4y1RWrmwosAK5y
# 1159  audio_features  3E3pb3qH11iny6TFDJvsg5
# 1160  audio_features  3yTkoTuiKRGL2VAlQd7xsC
# 1161  audio_features  4JE6agBLHGA5TaF6FlqfBD
#
#                                        uri  \
# 0     spotify:track:7lPN2DXiMsVn7XUKtOW1CS
# 1     spotify:track:5QO79kh1waicV47BqGRL3g
# 2     spotify:track:0VjIjW4GlUZAMYd2vXMi3b
# 3     spotify:track:4MzXwWMhyBbmu6hOcLVD49
# 4     spotify:track:5Kskr9LcNYa0tpt5f0ZEJx
# ...                                    ...
# 1157  spotify:track:4lUmnwRybYH7mMzf16xB0y
# 1158  spotify:track:1fzf9Aad4y1RWrmwosAK5y
# 1159  spotify:track:3E3pb3qH11iny6TFDJvsg5
# 1160  spotify:track:3yTkoTuiKRGL2VAlQd7xsC
# 1161  spotify:track:4JE6agBLHGA5TaF6FlqfBD
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/7lPN2DXiMsVn...
# 1     https://api.spotify.com/v1/tracks/5QO79kh1waic...
# 2     https://api.spotify.com/v1/tracks/0VjIjW4GlUZA...
# 3     https://api.spotify.com/v1/tracks/4MzXwWMhyBbm...
# 4     https://api.spotify.com/v1/tracks/5Kskr9LcNYa0...
# ...                                                 ...
# 1157  https://api.spotify.com/v1/tracks/4lUmnwRybYH7...
# 1158  https://api.spotify.com/v1/tracks/1fzf9Aad4y1R...
# 1159  https://api.spotify.com/v1/tracks/3E3pb3qH11in...
# 1160  https://api.spotify.com/v1/tracks/3yTkoTuiKRGL...
# 1161  https://api.spotify.com/v1/tracks/4JE6agBLHGA5...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/7lPN...       242014
# 1     https://api.spotify.com/v1/audio-analysis/5QO7...       215627
# 2     https://api.spotify.com/v1/audio-analysis/0VjI...       200040
# 3     https://api.spotify.com/v1/audio-analysis/4MzX...       205090
# 4     https://api.spotify.com/v1/audio-analysis/5Ksk...       205458
# ...                                                 ...          ...
# 1157  https://api.spotify.com/v1/audio-analysis/4lUm...       257428
# 1158  https://api.spotify.com/v1/audio-analysis/1fzf...       187310
# 1159  https://api.spotify.com/v1/audio-analysis/3E3p...       209299
# 1160  https://api.spotify.com/v1/audio-analysis/3yTk...       202204
# 1161  https://api.spotify.com/v1/audio-analysis/4JE6...       218755
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1157               4
# 1158               4
# 1159               4
# 1160               4
# 1161               4
#
# [1162 rows x 19 columns]

# %% [markdown]
# Finally, i saved the tesing dataset to `test_dataset.csv`. The testing dataset is stored in `data/test_dataset.csv`.

# %%
test_tracks_analysis.to_csv('test_dataset.csv', index=False)
